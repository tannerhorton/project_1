# %%
# Dependencies and Setup
import pandas as pd
import demoji
import matplotlib.pyplot as plt
import numpy as np
from matplotlib_venn import venn2
from matplotlib_venn import venn3

# File to Load
chart_path = "spotify_charts.csv"

# Read Chart Data File and store into Pandas DataFrames
chart_data = pd.read_csv(chart_path, encoding='utf-8')

# %% [markdown]
# <font size="5">Question 1</font>
#
# Which countries were the most influential on the global Spotify market?

# %%
# remove global from the regions column
regional_df = chart_data[chart_data["region"] != "Global"]

# %%
# count countries
len(regional_df['region'].unique())
# Out:
# 68

# %%
#create new df based on region
top_countries = regional_df.groupby(['region'])[['total streams','artist']].sum()
top_countries
# Out:
# /var/folders/bp/kkf4c1nj557c5frmyn420c7c0000gn/T/ipykernel_49365/929104590.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   top_countries = regional_df.groupby(['region'])[['total streams','artist']].sum()
#                       total streams
# region
# Argentina              1.953381e+10
# Australia              2.012821e+10
# Austria                2.703191e+09
# Belgium                3.883143e+09
# Bolivia                1.170959e+09
# ...                             ...
# United Arab Emirates   3.050062e+08
# United Kingdom         3.640880e+10
# United States          1.421321e+11
# Uruguay                1.323026e+09
# Vietnam                1.387636e+09
#
# [68 rows x 1 columns]

# %%
#sort df to find top streaming countries
sorted_countries = top_countries.sort_values('total streams', ascending = False)

#variable for top ten countries
top_ten = sorted_countries.head(10)

# %%
#create bar plot to show all countries streams 
sorted_countries_plot = sorted_countries.plot.bar(y='total streams', figsize =(30,30), width=.5, alpha=1, align="center", color = "lightgreen")

#adds title to bar chart  
plt.title("Countries Ranked By Streaming")

#label xaxis
plt.xlabel("Countries")

#lable yaxis
plt.ylabel("Streams (in billions)")

#rotate xticks to fit lables
plt.xticks(rotation = 90)

#export chart to pngs
plt.savefig("Countries_By_Streaming.png")

#show graph 
plt.show()

# %%
#create bar plot to show top 10 countries streams 
top_countries_plot = top_ten.plot.bar(y='total streams', figsize=(5, 5), width=.5, alpha=1, align="center", color = "lightgreen")

#add title
plt.title("Top Ten Countries By Streaming 2017-2021")

#label xaxis
plt.xlabel("Country")

#lable yaxis
plt.ylabel("Streams (in billions)")

#top_countries_plot.bar_label(top_countries["total streams"], label_type='edge')

#adjust graph layout 
plt.tight_layout()

#export chart to pngs
plt.savefig("Top_Ten_Countries_by_Streaming.png")

#show graph 
plt.show()

# %%
#Find total streams for US
us = regional_df.loc[regional_df["region"] == "United States"]

#sum total streams
us_streaming = us["total streams"].sum()
us_streaming
# Out:
# 142132086404.0

# %%
# #Find total streams overall
# overall = regional_df.loc[regional_df["region"] != "United States"]

#Sum total streams overall
overall_streaming = regional_df["total streams"].sum()

#Calcuate percent of streams that are from US
us_percent_streaming = (us_streaming/overall_streaming) * 100

#print streaming percentage
us_percent_streaming

print(f"The U.S. market makes up {us_percent_streaming}% of the total global Spotify streams from 2017-2021.")
# Out:
# The U.S. market makes up 20.78833584283174% of the total global Spotify streams from 2017-2021.

# %%
#BRANCHED CODE:
#pie chart comparing total US streams to all other regions:

#remove global and United States from the regions column
non_us_df = chart_data[(chart_data["region"] != "Global") & (chart_data["region"] != "United States")]
non_us_df['total streams'].sum()
# Out:
# 541578661193.0

# %%
#count countries - 
countries_count = [non_us_df['total streams'].sum(),us['total streams'].sum()]
countries_count

usvglobe_dict = pd.DataFrame({'Country': ['International', 'United States'],
                          'Total Countries':countries_count})

# %%
colors = ['silver', 'lightgreen']
usvglobe_dict.groupby(['Country']).sum().plot(kind='pie', y='Total Countries',autopct='%1.0f%%',colors=colors)

#export chart to pngs
plt.savefig("US_Streaming_Percentage.png")

plt.show()

# %% [markdown]
# <font size="5">Question 2</font>
#
# What are the top ranked songs globally and in the top streaming country?
#
# Top Songs 2017

# %%
# create data frame that only includes songs and streaming information for 2017
df_2017 = regional_df[(regional_df["date"] == 2017)]
df_2017.head()
# Out:
#    date                                      title          artist  \
# 0  2017  "All That Is or Ever Was or Ever Will Be"  Alan Silvestri
# 1  2017  "All That Is or Ever Was or Ever Will Be"  Alan Silvestri
# 2  2017               "Read All About It, Pt. III"     Emeli Sandé
# 3  2017               "Read All About It, Pt. III"     Emeli Sandé
# 4  2017               "Read All About It, Pt. III"     Emeli Sandé
#
#            region  total streams
# 0          Poland         3547.0
# 1          Turkey         3764.0
# 2         Belgium        15971.0
# 3  Czech Republic         6855.0
# 4         Denmark         6967.0

# %%
# double bracket to keep from changing to a series, this line also totals the non global streams for each song
songs_by_total_streams17=df_2017.groupby("title")[["total streams"]].sum()
songs_by_total_streams17
# Out:
#                                            total streams
# title
# "All That Is or Ever Was or Ever Will Be"         7311.0
# "Read All About It, Pt. III"                     57025.0
# #99                                              31826.0
# #Askip                                          296862.0
# #Biziz - feat. Lil Bege                         403591.0
# ...                                                  ...
# 불타오르네 FIRE                                      184096.0
# 에너제틱 Energetic                                   22362.0
# 에너제틱 Energetic - Prequel Remix                    1326.0
# 쩔어 DOPE                                         209493.0
# 피 땀 눈물                                           70997.0
#
# [18620 rows x 1 columns]

# %%
# sort dataframe of all 2017 songs by total streams in descending order 
songs_2017 = songs_by_total_streams17.sort_values('total streams', ascending = False)
songs_2017
# Out:
#                                     total streams
# title
# Shape of You                         1.485011e+09
# Despacito - Remix                    9.013116e+08
# Despacito (Featuring Daddy Yankee)   7.139895e+08
# Something Just Like This             6.848113e+08
# Unforgettable                        6.757906e+08
# ...                                           ...
# Eső                                  1.002000e+03
# Hlavarozbitajakslovensko             1.002000e+03
# Ir Vērts                             1.002000e+03
# ใครอีกคน                             1.002000e+03
# Mit Mondjak Még                      1.001000e+03
#
# [18620 rows x 1 columns]

# %%
#save top ten rows by streaming 
top_songs_2017 = songs_2017.head(10)

#print top ten
top_songs_2017.reset_index()
# Out:
#                                 title  total streams
# 0                        Shape of You   1.485011e+09
# 1                   Despacito - Remix   9.013116e+08
# 2  Despacito (Featuring Daddy Yankee)   7.139895e+08
# 3            Something Just Like This   6.848113e+08
# 4                       Unforgettable   6.757906e+08
# 5                             HUMBLE.   6.383807e+08
# 6                            rockstar   5.923562e+08
# 7     It Ain't Me (with Selena Gomez)   5.819983e+08
# 8                  That's What I Like   5.527117e+08
# 9                           Attention   5.482537e+08

# %%
#save top 100 rows by streaming for further analaysis section
top_songs_2017_ext = songs_2017.head(100).reset_index()
top_songs_2017_ext
# Out:
#                                  title  total streams
# 0                         Shape of You   1.485011e+09
# 1                    Despacito - Remix   9.013116e+08
# 2   Despacito (Featuring Daddy Yankee)   7.139895e+08
# 3             Something Just Like This   6.848113e+08
# 4                        Unforgettable   6.757906e+08
# ..                                 ...            ...
# 95    Lonely Together (feat. Rita Ora)   2.050320e+08
# 96                            Starving   2.013253e+08
# 97                                Weak   2.007547e+08
# 98                         Hear Me Now   1.997880e+08
# 99          Reggaetón Lento (Bailemos)   1.995196e+08
#
# [100 rows x 2 columns]

# %%
#create datframe for US 2017
df_US_2017 = regional_df[(regional_df["region"] == "United States") & (regional_df["date"] == 2017)]

#sort df by total streams 
songs_US_2017 = df_US_2017.sort_values('total streams', ascending = False)

#save top ten rows by streaming 
top_songs_US_2017 = songs_US_2017.head(10)

#print top ten
top_songs_US_2017
# Out:
#        date                    title                                   artist  \
# 20921  2017                  HUMBLE.                           Kendrick Lamar
# 11196  2017          Congratulations                       Post Malone, Quavo
# 48223  2017             Shape of You                               Ed Sheeran
# 33970  2017                 Mask Off                                   Future
# 12993  2017        Despacito - Remix  Luis Fonsi, Daddy Yankee, Justin Bieber
# 64210  2017                 rockstar                   Post Malone, 21 Savage
# 64085  2017  iSpy (feat. Lil Yachty)                                     KYLE
# 31732  2017                 Location                                   Khalid
# 268    2017           1-800-273-8255              Logic, Alessia Cara, Khalid
# 58449  2017            Unforgettable                 French Montana, Swae Lee
#
#               region  total streams
# 20921  United States    334342280.0
# 11196  United States    280284916.0
# 48223  United States    278916058.0
# 33970  United States    239307360.0
# 12993  United States    232299068.0
# 64210  United States    225517132.0
# 64085  United States    224773101.0
# 31732  United States    222266305.0
# 268    United States    216950629.0
# 58449  United States    215180711.0

# %%
#save top 100 rows by streaming for further analysis section
top_songs_US_2017_ext = songs_US_2017.head(100)
top_songs_US_2017_ext
# Out:
#        date                                       title  \
# 20921  2017                                     HUMBLE.
# 11196  2017                             Congratulations
# 48223  2017                                Shape of You
# 33970  2017                                    Mask Off
# 12993  2017                           Despacito - Remix
# ...     ...                                         ...
# 24992  2017                            I Like Me Better
# 63304  2017                               You Was Right
# 7235   2017                          Both (feat. Drake)
# 53132  2017  Swalla (feat. Nicki Minaj & Ty Dolla $ign)
# 42394  2017                                  Plain Jane
#
#                                         artist         region  total streams
# 20921                           Kendrick Lamar  United States    334342280.0
# 11196                       Post Malone, Quavo  United States    280284916.0
# 48223                               Ed Sheeran  United States    278916058.0
# 33970                                   Future  United States    239307360.0
# 12993  Luis Fonsi, Daddy Yankee, Justin Bieber  United States    232299068.0
# ...                                        ...            ...            ...
# 24992                                     Lauv  United States     74622442.0
# 63304                             Lil Uzi Vert  United States     74207159.0
# 7235                                Gucci Mane  United States     74153982.0
# 53132                             Jason Derulo  United States     73566694.0
# 42394                                A$AP Ferg  United States     73541226.0
#
# [100 rows x 5 columns]

# %%
# perform outer merge to include US streams and the sum of non global streams for each song
outer_merged = pd.merge(top_songs_2017, top_songs_US_2017, how="outer", on=["title"])
len(outer_merged)
outer_merged
# Out:
#                                  title  total streams_x    date  \
# 0                         Shape of You     1.485011e+09  2017.0
# 1                    Despacito - Remix     9.013116e+08  2017.0
# 2   Despacito (Featuring Daddy Yankee)     7.139895e+08     NaN
# 3             Something Just Like This     6.848113e+08     NaN
# 4                        Unforgettable     6.757906e+08  2017.0
# 5                              HUMBLE.     6.383807e+08  2017.0
# 6                             rockstar     5.923562e+08  2017.0
# 7      It Ain't Me (with Selena Gomez)     5.819983e+08     NaN
# 8                   That's What I Like     5.527117e+08     NaN
# 9                            Attention     5.482537e+08     NaN
# 10                     Congratulations              NaN  2017.0
# 11                            Mask Off              NaN  2017.0
# 12             iSpy (feat. Lil Yachty)              NaN  2017.0
# 13                            Location              NaN  2017.0
# 14                      1-800-273-8255              NaN  2017.0
#
#                                      artist         region  total streams_y
# 0                                Ed Sheeran  United States      278916058.0
# 1   Luis Fonsi, Daddy Yankee, Justin Bieber  United States      232299068.0
# 2                                       NaN            NaN              NaN
# 3                                       NaN            NaN              NaN
# 4                  French Montana, Swae Lee  United States      215180711.0
# 5                            Kendrick Lamar  United States      334342280.0
# 6                    Post Malone, 21 Savage  United States      225517132.0
# 7                                       NaN            NaN              NaN
# 8                                       NaN            NaN              NaN
# 9                                       NaN            NaN              NaN
# 10                       Post Malone, Quavo  United States      280284916.0
# 11                                   Future  United States      239307360.0
# 12                                     KYLE  United States      224773101.0
# 13                                   Khalid  United States      222266305.0
# 14              Logic, Alessia Cara, Khalid  United States      216950629.0

# %%
#create df for global vs us streams 
global_vs_us_2017 = pd.DataFrame({"Songs": outer_merged["title"], "US Streams": outer_merged["total streams_y"], "Global Streams": outer_merged["total streams_x"]})

#reset df index
global_vs_us_2017 = global_vs_us_2017.groupby(['Songs']).first().reset_index()

#fill empty values with 0
global_vs_us_2017['Global Streams'] = global_vs_us_2017['Global Streams'].fillna(0)

#fill empty values with 0
global_vs_us_2017['US Streams'] = global_vs_us_2017['US Streams'].fillna(0)

#print df
global_vs_us_2017
# Out:
#                                  Songs   US Streams  Global Streams
# 0                       1-800-273-8255  216950629.0    0.000000e+00
# 1                            Attention          0.0    5.482537e+08
# 2                      Congratulations  280284916.0    0.000000e+00
# 3   Despacito (Featuring Daddy Yankee)          0.0    7.139895e+08
# 4                    Despacito - Remix  232299068.0    9.013116e+08
# 5                              HUMBLE.  334342280.0    6.383807e+08
# 6      It Ain't Me (with Selena Gomez)          0.0    5.819983e+08
# 7                             Location  222266305.0    0.000000e+00
# 8                             Mask Off  239307360.0    0.000000e+00
# 9                         Shape of You  278916058.0    1.485011e+09
# 10            Something Just Like This          0.0    6.848113e+08
# 11                  That's What I Like          0.0    5.527117e+08
# 12                       Unforgettable  215180711.0    6.757906e+08
# 13             iSpy (feat. Lil Yachty)  224773101.0    0.000000e+00
# 14                            rockstar  225517132.0    5.923562e+08

# %%
#create x variable 
unique_top_songs = global_vs_us_2017["Songs"]

#define x variable
X = unique_top_songs

#define y variable #1
global_songs = global_vs_us_2017["Global Streams"]

#define y variable #2
us_songs = global_vs_us_2017["US Streams"]

#define length of x-axis
X_axis = np.arange(len(X))

#add colors 
color1 = "lightgreen"
color2 = "green"

#plot y variable #1
plt.bar(X_axis + 0.2, global_songs, 0.4, label = 'Global Songs', color=color1)

#plot y variable #2
plt.bar(X_axis - 0.2, us_songs, 0.4, label = 'US Songs', color=color2)

#plot x ticks
plt.xticks(X_axis, X)

#rotate x ticks
plt.xticks(rotation = 90)

#create labels 
plt.xlabel("Top Songs")
plt.ylabel("Total Streams (in billions)")

#create title 
plt.title("Global vs US Top Songs in 2017")

#plot legend 
plt.legend()

#export chart to pngs
plt.savefig("Global_vs_US_top_songs_2017.png")

#show plot
plt.show()

# %%
#find songs that appear on both top lists
both = global_vs_us_2017.loc[(global_vs_us_2017["US Streams"] > 0) & (global_vs_us_2017["Global Streams"] > 0)]       

#count number of songs  that appear on both top lists
US_song_count = both["Songs"].count()

#count number of songs on global top ten chart
song_count = len(top_songs_2017)

#find percent of US songs that appear in global top ten
song_percent_2017 = US_song_count/song_count * 100

#print findings 
print(f"The US charts had {song_percent_2017}% of the same top ten songs as the global charts in 2017.")
# Out:
# The US charts had 50.0% of the same top ten songs as the global charts in 2017.

# %% [markdown]
# Further analysis into the top 100 songs for 2017

# %%
# merge the extended data frames for topp 100 US songs and top 100 non-global song sums
top100_merged = pd.merge(top_songs_2017_ext, top_songs_US_2017_ext, how="outer", on=["title"])
len(outer_merged)
top100_merged
# Out:
#                                   title  total streams_x    date  \
# 0                          Shape of You     1.485011e+09  2017.0
# 1                     Despacito - Remix     9.013116e+08  2017.0
# 2    Despacito (Featuring Daddy Yankee)     7.139895e+08  2017.0
# 3              Something Just Like This     6.848113e+08  2017.0
# 4                         Unforgettable     6.757906e+08  2017.0
# ..                                  ...              ...     ...
# 135                               Moves              NaN  2017.0
# 136                       First Day Out              NaN  2017.0
# 137                       You Was Right              NaN  2017.0
# 138                  Both (feat. Drake)              NaN  2017.0
# 139                          Plain Jane              NaN  2017.0
#
#                                       artist         region  total streams_y
# 0                                 Ed Sheeran  United States      278916058.0
# 1    Luis Fonsi, Daddy Yankee, Justin Bieber  United States      232299068.0
# 2                                 Luis Fonsi  United States       94972759.0
# 3                 The Chainsmokers, Coldplay  United States      143171255.0
# 4                   French Montana, Swae Lee  United States      215180711.0
# ..                                       ...            ...              ...
# 135                                 Big Sean  United States       76563898.0
# 136                             Tee Grizzley  United States       75507666.0
# 137                             Lil Uzi Vert  United States       74207159.0
# 138                               Gucci Mane  United States       74153982.0
# 139                                A$AP Ferg  United States       73541226.0
#
# [140 rows x 6 columns]

# %%
#create df for global vs us streams 
global_vs_us_2017 = pd.DataFrame({"Songs": top100_merged["title"], "US Streams": top100_merged["total streams_y"], "Global Streams": top100_merged["total streams_x"]})

#reset df index
global_vs_us_2017 = global_vs_us_2017.groupby(['Songs']).first().reset_index()

#fill empty values with 0
global_vs_us_2017['Global Streams'] = global_vs_us_2017['Global Streams'].fillna(0)

#fill empty values with 0
global_vs_us_2017['US Streams'] = global_vs_us_2017['US Streams'].fillna(0)

#print df
global_vs_us_2017
# Out:
#                         Songs   US Streams  Global Streams
# 0              1-800-273-8255  216950629.0     445710786.0
# 1                   24K Magic   75607599.0     256687612.0
# 2    2U (feat. Justin Bieber)          0.0     381471303.0
# 3                  Ahora Dice          0.0     207600013.0
# 4                   Attention  121686882.0     548253656.0
# ..                        ...          ...             ...
# 135                goosebumps  196490882.0     250752479.0
# 136   iSpy (feat. Lil Yachty)  224773101.0     321574272.0
# 137         pick up the phone   83598597.0             0.0
# 138                  rockstar  225517132.0     592356193.0
# 139           wokeuplikethis*   78936148.0             0.0
#
# [140 rows x 3 columns]

# %%
#find songs that appear on both top lists
both = global_vs_us_2017.loc[(global_vs_us_2017["US Streams"] > 0) & (global_vs_us_2017["Global Streams"] > 0)]       

#count number of songs  that appear on both top lists
US_song_count = both["Songs"].count()

#count number of songs on global top ten chart
song_count = len(top_songs_2017_ext)

#find percent of US songs that appear in global top ten
song_percent_2017 = US_song_count/song_count * 100

#print findings 
print(f"The US charts had {song_percent_2017}% of the same top 100 songs as the global charts in 2017.")
# Out:
# The US charts had 60.0% of the same top 100 songs as the global charts in 2017.

# %%
#create venn diagram
venn2([set(top_songs_US_2017_ext["title"]),
       set(top_songs_2017_ext["title"])],
       set_labels=('United States', 'Global'),
       set_colors=('green', 'silver'))

#export chart to pngs
plt.savefig("_top_songs_2017_venn.png")

# %% [markdown]
# Top Songs 2018

# %%
# create data frame that only includes songs and streaming information for 2018
df_2018 = regional_df[(regional_df["date"] == 2018)]
df_2018.head()
# Out:
#        date                         title                              artist  \
# 66579  2018                             !                            O.S.T.R.
# 66580  2018                !I'll Be Back!                               Rilès
# 66581  2018             "42" - From SR3MM  Rae Sremmurd, Swae Lee, Slim Jxmmi
# 66582  2018        "Jag fakking hatar er"              ODZ, Young Earth Sauce
# 66583  2018  "Read All About It, Pt. III"                         Emeli Sandé
#
#               region  total streams
# 66579         Poland       123714.0
# 66580         France        36343.0
# 66581  United States       297731.0
# 66582         Sweden       235489.0
# 66583        Belgium         5479.0

# %%
# double bracket to keep from changing to a series, this line also totals the non global streams for each song
songs_by_total_streams18=df_2018.groupby("title")[["total streams"]].sum()
songs_by_total_streams18
# Out:
#                               total streams
# title
# !                                  123714.0
# !I'll Be Back!                      36343.0
# "42" - From SR3MM                  297731.0
# "Jag fakking hatar er"             235489.0
# "Read All About It, Pt. III"         8888.0
# ...                                     ...
# 운명 The Chance of Love                1070.0
# 지켜줄게 Save You                        3900.0
# 파란 봄                                 4237.0
# 항상 (HANGSANG)                      141250.0
# 혼자 Nobody knows                      6416.0
#
# [23046 rows x 1 columns]

# %%
# check to make sure it is still a dataframe and not a series 
type(songs_by_total_streams18)
# Out:
# pandas.core.frame.DataFrame

# %%
# sort dataframe of all 2018 songsand streaming numbers by total streams in descending order 
songs_2018 = songs_by_total_streams18.sort_values('total streams', ascending = False)
songs_2018
# Out:
#                                                   total streams
# title
# God's Plan                                         1.104866e+09
# SAD!                                               7.406785e+08
# In My Feelings                                     6.926642e+08
# Better Now                                         6.640538e+08
# Psycho (feat. Ty Dolla $ign)                       6.609611e+08
# ...                                                         ...
# Homework As$ignment                                1.002000e+03
# Girl on Fire                                       1.002000e+03
# Zaudējam Brāli                                     1.002000e+03
# So Xclusive (feat. K-Slicc, Lo$Ta & Badazz Luck)   1.001000e+03
# La Guitarra - MTV Unplugged                        1.001000e+03
#
# [23046 rows x 1 columns]

# %%
# save top ten rows by streaming 
top_songs_2018 = songs_2018.head(10)

#print top ten
top_songs_2018.reset_index()
# Out:
#                             title  total streams
# 0                      God's Plan   1.104866e+09
# 1                            SAD!   7.406785e+08
# 2                  In My Feelings   6.926642e+08
# 3                      Better Now   6.640538e+08
# 4    Psycho (feat. Ty Dolla $ign)   6.609611e+08
# 5                       I Like It   6.562499e+08
# 6        One Kiss (with Dua Lipa)   6.338316e+08
# 7  Girls Like You (feat. Cardi B)   5.914740e+08
# 8                    Lucid Dreams   5.763290e+08
# 9                           IDGAF   5.694874e+08

# %%
#save top 100 rows by streaming for further analysis section, reset index for venn diagram
top_songs_2018_ext = songs_2018.head(100).reset_index()
top_songs_2018_ext
# Out:
#                                                 title  total streams
# 0                                          God's Plan   1.104866e+09
# 1                                                SAD!   7.406785e+08
# 2                                      In My Feelings   6.926642e+08
# 3                                          Better Now   6.640538e+08
# 4                        Psycho (feat. Ty Dolla $ign)   6.609611e+08
# ..                                                ...            ...
# 95                                           Criminal   2.157794e+08
# 96                  Pray For Me (with Kendrick Lamar)   2.139540e+08
# 97                                        No Es Justo   2.124644e+08
# 98                                      Unforgettable   2.118231e+08
# 99  Let Me Go (with Alesso, Florida Georgia Line &...   2.113229e+08
#
# [100 rows x 2 columns]

# %%
#create datframe for US 2017
df_US_2018 = regional_df[(regional_df["region"] == "United States") & (regional_df["date"] == 2018)]

#sort df by total streams 
songs_US_2018 = df_US_2018.sort_values('total streams', ascending = False)

#save top ten rows by streaming 
top_songs_US_2018 = songs_US_2018.head(10)

#print top ten
top_songs_US_2018
# Out:
#         date                         title                        artist  \
# 91563   2018                    God's Plan                         Drake
# 122834  2018                          SAD!                  XXXTENTACION
# 119442  2018  Psycho (feat. Ty Dolla $ign)                   Post Malone
# 106537  2018                  Lucid Dreams                    Juice WRLD
# 105578  2018      Look Alive (feat. Drake)                    BlocBoy JB
# 112843  2018                 Nice For What                         Drake
# 74661   2018                    Better Now                   Post Malone
# 98444   2018                In My Feelings                         Drake
# 110459  2018                     Moonlight                  XXXTENTACION
# 96383   2018                     I Like It  Cardi B, Bad Bunny, J Balvin
#
#                region  total streams
# 91563   United States    453226629.0
# 122834  United States    332633597.0
# 119442  United States    306877012.0
# 106537  United States    299907223.0
# 105578  United States    266861797.0
# 112843  United States    263455062.0
# 74661   United States    254098207.0
# 98444   United States    245715031.0
# 110459  United States    245410462.0
# 96383   United States    240430007.0

# %%
#save top 100 rows by streaming for further analysis section, then reset index for venn diagram
top_songs_US_2018_ext = songs_US_2018.head(100)
top_songs_US_2018_ext
# Out:
#         date                           title  \
# 91563   2018                      God's Plan
# 122834  2018                            SAD!
# 119442  2018    Psycho (feat. Ty Dolla $ign)
# 106537  2018                    Lucid Dreams
# 105578  2018        Look Alive (feat. Drake)
# ...      ...                             ...
# 97707   2018                           IDGAF
# 93908   2018                          Heaven
# 74561   2018                          Better
# 106635  2018  Lucky You (feat. Joyner Lucas)
# 99764   2018                     Jackie Chan
#
#                                    artist         region  total streams
# 91563                               Drake  United States    453226629.0
# 122834                       XXXTENTACION  United States    332633597.0
# 119442                        Post Malone  United States    306877012.0
# 106537                         Juice WRLD  United States    299907223.0
# 105578                         BlocBoy JB  United States    266861797.0
# ...                                   ...            ...            ...
# 97707                            Dua Lipa  United States     86397943.0
# 93908                          Kane Brown  United States     86069146.0
# 74561                              Khalid  United States     85156431.0
# 106635                             Eminem  United States     85144271.0
# 99764   Tiësto, Dzeko, Preme, Post Malone  United States     85122638.0
#
# [100 rows x 5 columns]

# %%
#merge the top ten US data frame with the top ten non-global data frame 
outer_merged18 = pd.merge(top_songs_2018, top_songs_US_2018, how="outer", on=["title"])
outer_merged18
# Out:
#                              title  total streams_x    date  \
# 0                       God's Plan     1.104866e+09  2018.0
# 1                             SAD!     7.406785e+08  2018.0
# 2                   In My Feelings     6.926642e+08  2018.0
# 3                       Better Now     6.640538e+08  2018.0
# 4     Psycho (feat. Ty Dolla $ign)     6.609611e+08  2018.0
# 5                        I Like It     6.562499e+08  2018.0
# 6         One Kiss (with Dua Lipa)     6.338316e+08     NaN
# 7   Girls Like You (feat. Cardi B)     5.914740e+08     NaN
# 8                     Lucid Dreams     5.763290e+08  2018.0
# 9                            IDGAF     5.694874e+08     NaN
# 10        Look Alive (feat. Drake)              NaN  2018.0
# 11                   Nice For What              NaN  2018.0
# 12                       Moonlight              NaN  2018.0
#
#                           artist         region  total streams_y
# 0                          Drake  United States      453226629.0
# 1                   XXXTENTACION  United States      332633597.0
# 2                          Drake  United States      245715031.0
# 3                    Post Malone  United States      254098207.0
# 4                    Post Malone  United States      306877012.0
# 5   Cardi B, Bad Bunny, J Balvin  United States      240430007.0
# 6                            NaN            NaN              NaN
# 7                            NaN            NaN              NaN
# 8                     Juice WRLD  United States      299907223.0
# 9                            NaN            NaN              NaN
# 10                    BlocBoy JB  United States      266861797.0
# 11                         Drake  United States      263455062.0
# 12                  XXXTENTACION  United States      245410462.0

# %%
#create df for global vs us streams 
global_vs_us_2018 = pd.DataFrame({"Songs": outer_merged18["title"], "US Streams": outer_merged18["total streams_y"], "Global Streams": outer_merged18["total streams_x"]})

#reset df index
global_vs_us_2018 = global_vs_us_2018.groupby(['Songs']).first().reset_index()

#fill empty values with 0
global_vs_us_2018['Global Streams'] = global_vs_us_2018['Global Streams'].fillna(0)

#fill empty values with 0
global_vs_us_2018['US Streams'] = global_vs_us_2018['US Streams'].fillna(0)

#print df
global_vs_us_2018
# Out:
#                              Songs   US Streams  Global Streams
# 0                       Better Now  254098207.0    6.640538e+08
# 1   Girls Like You (feat. Cardi B)          0.0    5.914740e+08
# 2                       God's Plan  453226629.0    1.104866e+09
# 3                        I Like It  240430007.0    6.562499e+08
# 4                            IDGAF          0.0    5.694874e+08
# 5                   In My Feelings  245715031.0    6.926642e+08
# 6         Look Alive (feat. Drake)  266861797.0    0.000000e+00
# 7                     Lucid Dreams  299907223.0    5.763290e+08
# 8                        Moonlight  245410462.0    0.000000e+00
# 9                    Nice For What  263455062.0    0.000000e+00
# 10        One Kiss (with Dua Lipa)          0.0    6.338316e+08
# 11    Psycho (feat. Ty Dolla $ign)  306877012.0    6.609611e+08
# 12                            SAD!  332633597.0    7.406785e+08

# %%
#create x vaiable 
unique_top_songs = global_vs_us_2018["Songs"]

#define x variable
X = unique_top_songs

#define y variable #1
global_songs = global_vs_us_2018["Global Streams"]

#define y variable #2
us_songs = global_vs_us_2018["US Streams"]

#define length of x-axis
X_axis = np.arange(len(X))

#add colors 
color1 = "lightgreen"
color2 = "green"

#plot y variable #1
plt.bar(X_axis + 0.2, global_songs, 0.4, label = 'Global Songs', color=color1)

#plot y variable #2
plt.bar(X_axis - 0.2, us_songs, 0.4, label = 'US Songs', color=color2)

#plot x ticks
plt.xticks(X_axis, X)

#rotate x ticks
plt.xticks(rotation = 90)

#create labels 
plt.xlabel("Top Songs")
plt.ylabel("Total Streams (in billions)")

#create title 
plt.title("Global vs US Top Songs in 2018")

#plot legend 
plt.legend()

#export chart to pngs
plt.savefig("Global_vs_US_top_songs_2018.png")

#show plot
plt.show()

# %%
#find songs that appear on both top lists
both = global_vs_us_2018.loc[(global_vs_us_2018["US Streams"] > 0) & (global_vs_us_2018["Global Streams"] > 0)]       

#count number of songs  that appear on both top lists
US_song_count = both["Songs"].count()

#count number of songs on global top ten chart
song_count = len(top_songs_2018)

#find percent of US songs that appear in global top ten
song_percent_2018 = US_song_count/song_count * 100

#print findings 
print(f"The US charts had {song_percent_2018}% of the same top ten songs as the global charts in 2018.")
# Out:
# The US charts had 70.0% of the same top ten songs as the global charts in 2018.

# %% [markdown]
# Further analysis into the top 100 songs for 2018

# %%
# merge extended top song data frames for 2018 (top 100 US and top 100 non-global summed)
top100_merged18 = pd.merge(top_songs_2018_ext, top_songs_US_2018_ext, how="outer", on=["title"])
top100_merged18
# Out:
#                                    title  total streams_x    date  \
# 0                             God's Plan     1.104866e+09  2018.0
# 1                                   SAD!     7.406785e+08  2018.0
# 2                         In My Feelings     6.926642e+08  2018.0
# 3                             Better Now     6.640538e+08  2018.0
# 4           Psycho (feat. Ty Dolla $ign)     6.609611e+08  2018.0
# ..                                   ...              ...     ...
# 132                              Tequila              NaN  2018.0
# 133                   Wake Up in the Sky              NaN  2018.0
# 134  The Way Life Goes (feat. Oh Wonder)              NaN  2018.0
# 135                               Heaven              NaN  2018.0
# 136       Lucky You (feat. Joyner Lucas)              NaN  2018.0
#
#                                   artist         region  total streams_y
# 0                                  Drake  United States      453226629.0
# 1                           XXXTENTACION  United States      332633597.0
# 2                                  Drake  United States      245715031.0
# 3                            Post Malone  United States      254098207.0
# 4                            Post Malone  United States      306877012.0
# ..                                   ...            ...              ...
# 132                           Dan + Shay  United States       90133833.0
# 133  Gucci Mane, Bruno Mars, Kodak Black  United States       89822965.0
# 134                         Lil Uzi Vert  United States       87844456.0
# 135                           Kane Brown  United States       86069146.0
# 136                               Eminem  United States       85144271.0
#
# [137 rows x 6 columns]

# %%
#create df for global vs us streams 
global_vs_us_2018 = pd.DataFrame({"Songs": top100_merged18["title"], "US Streams": top100_merged18["total streams_y"], "Global Streams": top100_merged18["total streams_x"]})

#reset df index
global_vs_us_2018 = global_vs_us_2018.groupby(['Songs']).first().reset_index()

#fill empty values with 0
global_vs_us_2018['Global Streams'] = global_vs_us_2018['Global Streams'].fillna(0)

#fill empty values with 0
global_vs_us_2018['US Streams'] = global_vs_us_2018['US Streams'].fillna(0)

#print df
global_vs_us_2018
# Out:
#                                                  Songs   US Streams  \
# 0          1, 2, 3 (feat. Jason Derulo & De La Ghetto)          0.0
# 1                                       1-800-273-8255   95414792.0
# 2                                                 2002          0.0
# 3                               All Girls Are The Same  143447522.0
# 4                             All The Stars (with SZA)  185113340.0
# ..                                                 ...          ...
# 132                                           rockstar  112816631.0
# 133                         rockstar (feat. 21 Savage)  152300383.0
# 134                                      thank u, next  124951058.0
# 135  the remedy for a broken heart (why am I so in ...   91695752.0
# 136                                    Échame La Culpa          0.0
#
#      Global Streams
# 0       223727071.0
# 1               0.0
# 2       283803434.0
# 3               0.0
# 4       454335070.0
# ..              ...
# 132     339074250.0
# 133     390856859.0
# 134     353741985.0
# 135             0.0
# 136     317355107.0
#
# [137 rows x 3 columns]

# %%
#find songs that appear on both top lists
both = global_vs_us_2018.loc[(global_vs_us_2018["US Streams"] > 0) & (global_vs_us_2018["Global Streams"] > 0)]       

#count number of songs  that appear on both top lists
US_song_count = both["Songs"].count()

#count number of songs on global top ten chart
song_count = len(top_songs_2018_ext)

#find percent of US songs that appear in global top ten
song_percent_2018 = US_song_count/song_count * 100

#print findings 
print(f"The US charts had {song_percent_2018}% of the same top 100 songs as the global charts in 2018.")
# Out:
# The US charts had 63.0% of the same top 100 songs as the global charts in 2018.

# %%
#create venn diagram
venn2([set(top_songs_US_2018_ext["title"]),
       set(top_songs_2018_ext["title"])],
       set_labels=('United States', 'Global'),
       set_colors=('green', 'silver'))

#export chart to pngs
plt.savefig("_top_songs_2018_venn.png")

# %% [markdown]
# Top Songs 2019

# %%
# create data frame that only includes songs and streaming information for 2018
df_2019 = regional_df[(regional_df["date"] == 2019)]
df_2019.head()
# Out:
#         date title        artist          region  total streams
# 149228  2019     !   Samey, Gleb  Czech Republic        56857.0
# 149229  2019     !   Samey, Gleb        Slovakia       364843.0
# 149230  2019     !  Trippie Redd       Australia        32996.0
# 149231  2019     !  Trippie Redd         Belgium         6951.0
# 149232  2019     !  Trippie Redd          Canada       232153.0

# %%
# double bracket to keep from changing to a series, this line also totals the non global streams for each song
songs_by_total_streams19=df_2019.groupby("title")[["total streams"]].sum()
songs_by_total_streams19
# Out:
#                         total streams
# title
# !                           3529796.0
# "Jag fakking hatar er"       390192.0
# #24                           90529.0
# #302                         591135.0
# #31#                        1308234.0
# ...                               ...
# 龍舌蘭                         1620275.0
# 끝                             52822.0
# 달라달라 (DALLA DALLA)         22250122.0
# 달라달라 DALLA DALLA            3176849.0
# 믿어줄래                          57825.0
#
# [25972 rows x 1 columns]

# %%
# sort dataframe of songs from this year by total streams in descending order 
songs_2019 = songs_by_total_streams19.sort_values('total streams', ascending = False)
songs_2019
# Out:
#                                                total streams
# title
# Señorita                                        1.069771e+09
# bad guy                                         1.047935e+09
# Sunflower - Spider-Man: Into the Spider-Verse   9.419000e+08
# 7 rings                                         9.260560e+08
# I Don't Care (with Justin Bieber)               8.089955e+08
# ...                                                      ...
# Gomari                                          1.004000e+03
# Lumevarjude Vahel                               1.004000e+03
# Последно предупреждение                         1.003000e+03
# Raju reede                                      1.002000e+03
# 15 Magamata Ööd                                 1.001000e+03
#
# [25972 rows x 1 columns]

# %%
# save top ten rows by streaming 
top_songs_2019 = songs_2019.head(10)

# print top ten
top_songs_2019.reset_index()
# Out:
#                                            title  total streams
# 0                                       Señorita   1.069771e+09
# 1                                        bad guy   1.047935e+09
# 2  Sunflower - Spider-Man: Into the Spider-Verse   9.419000e+08
# 3                                        7 rings   9.260560e+08
# 4              I Don't Care (with Justin Bieber)   8.089955e+08
# 5                              Someone You Loved   7.602305e+08
# 6                                   Dance Monkey   7.549729e+08
# 7                                        Shallow   6.777083e+08
# 8                                           Wow.   6.767703e+08
# 9                                      Con Calma   6.362816e+08

# %%
# save top 100 rows by streaming for further analysis section
top_songs_2019_ext = songs_2019.head(100).reset_index()
#print
top_songs_2019_ext.reset_index()
# Out:
#     index                                          title  total streams
# 0       0                                       Señorita   1.069771e+09
# 1       1                                        bad guy   1.047935e+09
# 2       2  Sunflower - Spider-Man: Into the Spider-Verse   9.419000e+08
# 3       3                                        7 rings   9.260560e+08
# 4       4              I Don't Care (with Justin Bieber)   8.089955e+08
# ..    ...                                            ...            ...
# 95     95                      Ella Quiere Beber - Remix   2.246481e+08
# 96     96                                           Suge   2.244207e+08
# 97     97                                          11 PM   2.204121e+08
# 98     98                                     In My Mind   2.200539e+08
# 99     99                                          a lot   2.188878e+08
#
# [100 rows x 3 columns]

# %%
#create datframe for US from this year 
df_US_2019 = regional_df[(regional_df["region"] == "United States") & (regional_df["date"] == 2019)]

#sort df by total streams 
songs_US_2019 = df_US_2019.sort_values('total streams', ascending = False)

#save top ten rows by streaming 
top_songs_US_2019 = songs_US_2019.head(10)

#print top ten
top_songs_US_2019
# Out:
#         date                                          title  \
# 211054  2019  Sunflower - Spider-Man: Into the Spider-Verse
# 221240  2019                                           Wow.
# 150460  2019                                        7 rings
# 188644  2019                                   MIDDLE CHILD
# 222912  2019                                        bad guy
# 173001  2019                        Going Bad (feat. Drake)
# 216312  2019                                    Truth Hurts
# 202689  2019                                         Ransom
# 166353  2019               Drip Too Hard (Lil Baby & Gunna)
# 211530  2019                        Swervin (feat. 6ix9ine)
#
#                         artist         region  total streams
# 211054   Post Malone, Swae Lee  United States    389059531.0
# 221240             Post Malone  United States    297846574.0
# 150460           Ariana Grande  United States    280698165.0
# 188644                 J. Cole  United States    277704991.0
# 222912           Billie Eilish  United States    266782562.0
# 173001               Meek Mill  United States    242889031.0
# 216312                   Lizzo  United States    239980228.0
# 202689               Lil Tecca  United States    214034982.0
# 166353                Lil Baby  United States    208752215.0
# 211530  A Boogie Wit da Hoodie  United States    205758012.0

# %%
#save top 100 rows by streaming for further analysis section
top_songs_US_2019_ext = songs_US_2019.head(100)
top_songs_US_2019_ext
# Out:
#         date                                          title  \
# 211054  2019  Sunflower - Spider-Man: Into the Spider-Verse
# 221240  2019                                           Wow.
# 150460  2019                                        7 rings
# 188644  2019                                   MIDDLE CHILD
# 222912  2019                                        bad guy
# ...      ...                                            ...
# 224145  2019                                i'm so tired...
# 224570  2019                           lovely (with Khalid)
# 224963  2019                                     ocean eyes
# 180898  2019                                       It's You
# 155781  2019                                     Be Alright
#
#                        artist         region  total streams
# 211054  Post Malone, Swae Lee  United States    389059531.0
# 221240            Post Malone  United States    297846574.0
# 150460          Ariana Grande  United States    280698165.0
# 188644                J. Cole  United States    277704991.0
# 222912          Billie Eilish  United States    266782562.0
# ...                       ...            ...            ...
# 224145      Lauv, Troye Sivan  United States     84670678.0
# 224570          Billie Eilish  United States     84428762.0
# 224963          Billie Eilish  United States     83628378.0
# 180898              Ali Gatie  United States     82823503.0
# 155781             Dean Lewis  United States     82632480.0
#
# [100 rows x 5 columns]

# %%
#merge the top ten US data frame with the top ten non-global data frame 
outer_merged19 = pd.merge(top_songs_2019, top_songs_US_2019, how="outer", on=["title"])
outer_merged19
# Out:
#                                             title  total streams_x    date  \
# 0                                        Señorita     1.069771e+09     NaN
# 1                                         bad guy     1.047935e+09  2019.0
# 2   Sunflower - Spider-Man: Into the Spider-Verse     9.419000e+08  2019.0
# 3                                         7 rings     9.260560e+08  2019.0
# 4               I Don't Care (with Justin Bieber)     8.089955e+08     NaN
# 5                               Someone You Loved     7.602305e+08     NaN
# 6                                    Dance Monkey     7.549729e+08     NaN
# 7                                         Shallow     6.777083e+08     NaN
# 8                                            Wow.     6.767703e+08  2019.0
# 9                                       Con Calma     6.362816e+08     NaN
# 10                                   MIDDLE CHILD              NaN  2019.0
# 11                        Going Bad (feat. Drake)              NaN  2019.0
# 12                                    Truth Hurts              NaN  2019.0
# 13                                         Ransom              NaN  2019.0
# 14               Drip Too Hard (Lil Baby & Gunna)              NaN  2019.0
# 15                        Swervin (feat. 6ix9ine)              NaN  2019.0
#
#                     artist         region  total streams_y
# 0                      NaN            NaN              NaN
# 1            Billie Eilish  United States      266782562.0
# 2    Post Malone, Swae Lee  United States      389059531.0
# 3            Ariana Grande  United States      280698165.0
# 4                      NaN            NaN              NaN
# 5                      NaN            NaN              NaN
# 6                      NaN            NaN              NaN
# 7                      NaN            NaN              NaN
# 8              Post Malone  United States      297846574.0
# 9                      NaN            NaN              NaN
# 10                 J. Cole  United States      277704991.0
# 11               Meek Mill  United States      242889031.0
# 12                   Lizzo  United States      239980228.0
# 13               Lil Tecca  United States      214034982.0
# 14                Lil Baby  United States      208752215.0
# 15  A Boogie Wit da Hoodie  United States      205758012.0

# %%
#create df for global vs us streams 
global_vs_us_2019 = pd.DataFrame({"Songs": outer_merged19["title"], "US Streams": outer_merged19["total streams_y"], "Global Streams": outer_merged19["total streams_x"]})

#reset df index
global_vs_us_2019 = global_vs_us_2019.groupby(['Songs']).first().reset_index()

#fill empty values with 0
global_vs_us_2019['Global Streams'] = global_vs_us_2019['Global Streams'].fillna(0)

#fill empty values with 0
global_vs_us_2019['US Streams'] = global_vs_us_2019['US Streams'].fillna(0)

#print df
global_vs_us_2019
# Out:
#                                             Songs   US Streams  Global Streams
# 0                                         7 rings  280698165.0    9.260560e+08
# 1                                       Con Calma          0.0    6.362816e+08
# 2                                    Dance Monkey          0.0    7.549729e+08
# 3                Drip Too Hard (Lil Baby & Gunna)  208752215.0    0.000000e+00
# 4                         Going Bad (feat. Drake)  242889031.0    0.000000e+00
# 5               I Don't Care (with Justin Bieber)          0.0    8.089955e+08
# 6                                    MIDDLE CHILD  277704991.0    0.000000e+00
# 7                                          Ransom  214034982.0    0.000000e+00
# 8                                        Señorita          0.0    1.069771e+09
# 9                                         Shallow          0.0    6.777083e+08
# 10                              Someone You Loved          0.0    7.602305e+08
# 11  Sunflower - Spider-Man: Into the Spider-Verse  389059531.0    9.419000e+08
# 12                        Swervin (feat. 6ix9ine)  205758012.0    0.000000e+00
# 13                                    Truth Hurts  239980228.0    0.000000e+00
# 14                                           Wow.  297846574.0    6.767703e+08
# 15                                        bad guy  266782562.0    1.047935e+09

# %%
#create x vaiable 
unique_top_songs = global_vs_us_2019["Songs"]

#define x variable
X = unique_top_songs

#define y variable #1
global_songs = global_vs_us_2019["Global Streams"]

#define y variable #2
us_songs = global_vs_us_2019["US Streams"]

#define length of x-axis
X_axis = np.arange(len(X))

#add colors 
color1 = "lightgreen"
color2 = "green"

#plot y variable #1
plt.bar(X_axis + 0.2, global_songs, 0.4, label = 'Global Songs', color=color1)

#plot y variable #2
plt.bar(X_axis - 0.2, us_songs, 0.4, label = 'US Songs', color=color2)

#plot x ticks
plt.xticks(X_axis, X)

#rotate x ticks
plt.xticks(rotation = 90)

#create labels 
plt.xlabel("Top Songs")
plt.ylabel("Total Streams (in billions)")

#create title 
plt.title("Global vs US Top Songs in 2019")

#plot legend 
plt.legend()

#export chart to pngs
plt.savefig("Global_vs_US_top_songs_2019.png")

#show plot
plt.show()

# %%
#find songs that appear on both top lists
both = global_vs_us_2019.loc[(global_vs_us_2019["US Streams"] > 0) & (global_vs_us_2019["Global Streams"] > 0)]       

#count number of songs  that appear on both top lists
US_song_count = both["Songs"].count()

#count number of songs on global top ten chart
song_count = len(top_songs_2019)

#find percent of US songs that appear in global top ten
song_percent_2019 = US_song_count/song_count * 100

#print findings 
print(f"The US charts had {song_percent_2019}% of the same top ten songs as the global charts in 2019.")
# Out:
# The US charts had 40.0% of the same top ten songs as the global charts in 2019.

# %% [markdown]
# Further analysis into the top 100 songs in 2019

# %%
# merge extended top song data frames for 2018 (top 100 US and top 100 non-global summed)
top100_merged19 = pd.merge(top_songs_2019_ext, top_songs_US_2019_ext, how="outer", on=["title"])
top100_merged19
# Out:
#                                              title  total streams_x    date  \
# 0                                         Señorita     1.069771e+09  2019.0
# 1                                          bad guy     1.047935e+09  2019.0
# 2    Sunflower - Spider-Man: Into the Spider-Verse     9.419000e+08  2019.0
# 3                                          7 rings     9.260560e+08  2019.0
# 4                I Don't Care (with Justin Bieber)     8.089955e+08  2019.0
# ..                                             ...              ...     ...
# 132                               I Like Me Better              NaN  2019.0
# 133                                          Money              NaN  2019.0
# 134                                        Tequila              NaN  2019.0
# 135                           lovely (with Khalid)              NaN  2019.0
# 136                                     ocean eyes              NaN  2019.0
#
#                            artist         region  total streams_y
# 0    Shawn Mendes, Camila Cabello  United States      178554964.0
# 1                   Billie Eilish  United States      266782562.0
# 2           Post Malone, Swae Lee  United States      389059531.0
# 3                   Ariana Grande  United States      280698165.0
# 4                      Ed Sheeran  United States      144025311.0
# ..                            ...            ...              ...
# 132                          Lauv  United States       86316296.0
# 133                       Cardi B  United States       85438932.0
# 134                    Dan + Shay  United States       85154851.0
# 135                 Billie Eilish  United States       84428762.0
# 136                 Billie Eilish  United States       83628378.0
#
# [137 rows x 6 columns]

# %%
#create df for global vs us streams 
global_vs_us_2019 = pd.DataFrame({"Songs": top100_merged19["title"], "US Streams": top100_merged19["total streams_y"], "Global Streams": top100_merged19["total streams_x"]})

#reset df index
global_vs_us_2019 = global_vs_us_2019.groupby(['Songs']).first().reset_index()

#fill empty values with 0
global_vs_us_2019['Global Streams'] = global_vs_us_2019['Global Streams'].fillna(0)

#fill empty values with 0
global_vs_us_2019['US Streams'] = global_vs_us_2019['US Streams'].fillna(0)

#print df
global_vs_us_2019
# Out:
#                           Songs   US Streams  Global Streams
# 0                         11 PM          0.0     220412138.0
# 1       223's (feat. 9lokknine)   95746470.0             0.0
# 2                       7 rings  280698165.0     926055999.0
# 3                    Adan y Eva          0.0     327371199.0
# 4        All Girls Are The Same  109923109.0             0.0
# ..                          ...          ...             ...
# 132                  ocean eyes   83628378.0             0.0
# 133  rockstar (feat. 21 Savage)  130084723.0     297820907.0
# 134               thank u, next  182180801.0     520422655.0
# 135       when the party's over  177211774.0     431653372.0
# 136           wish you were gay  111756933.0     244502614.0
#
# [137 rows x 3 columns]

# %%
#find songs that appear on both top lists
both = global_vs_us_2019.loc[(global_vs_us_2019["US Streams"] > 0) & (global_vs_us_2019["Global Streams"] > 0)]       

#count number of songs  that appear on both top lists
US_song_count = both["Songs"].count()

#count number of songs on global top ten chart
song_count = len(top_songs_2019_ext)

#find percent of US songs that appear in global top ten
song_percent_2019 = US_song_count/song_count * 100

#print findings 
print(f"The US charts had {song_percent_2019}% of the same top 100 songs as the global charts in 2019.")
# Out:
# The US charts had 63.0% of the same top 100 songs as the global charts in 2019.

# %%
#create venn diagram
venn2([set(top_songs_US_2019_ext["title"]),
       set(top_songs_2019_ext["title"])],
       set_labels=('United States', 'Global'),
       set_colors=('green', 'silver'))

#export chart to pngs
plt.savefig("_top_songs_2019_venn.png")

# %% [markdown]
# Top Songs 2020

# %%
# create data frame that only includes songs and streaming information for 2018
df_2020 = regional_df[(regional_df["date"] == 2020)]
df_2020.head()
# Out:
#         date          title                artist    region  total streams
# 228430  2020              !           Samey, Gleb  Slovakia       133718.0
# 228431  2020  #%_! Dig Selv           Artigeardit   Denmark        85639.0
# 228432  2020           #213                    YL    France        49321.0
# 228433  2020            #24  Dolu Kadehi Ters Tut    Turkey       649313.0
# 228434  2020            #24  ProfJam, benji price  Portugal       131173.0

# %%
# double bracket to keep from changing to a series, this line also totals the non global streams for each song
songs_by_total_streams20=df_2020.groupby("title")[["total streams"]].sum()
songs_by_total_streams20
# Out:
#                       total streams
# title
# !                          133718.0
# #%_! Dig Selv               85639.0
# #213                        49321.0
# #24                        780486.0
# #25                        264912.0
# ...                             ...
# 돌덩이                        404404.0
# 시작                        8938614.0
# 우린 친구뿐일까                     6075.0
# 지코 아무노래                     20783.0
# 해와 달처럼 Day and Night        74178.0
#
# [30264 rows x 1 columns]

# %%
# sort dataframe of songs from this year by total streams in descending order 
songs_2020 = songs_by_total_streams20.sort_values('total streams', ascending = False)
songs_2020
# Out:
#                            total streams
# title
# Blinding Lights             1.634833e+09
# Dance Monkey                1.174788e+09
# Roses - Imanbek Remix       1.002278e+09
# Don't Start Now             9.845018e+08
# The Box                     9.639734e+08
# ...                                  ...
# Jäätunud Jäljed             1.002000e+03
# Vesturbær (feat. Class B)   1.002000e+03
# Junkies Ate My Poodle       1.002000e+03
# ده و ده                     1.001000e+03
# Piccola                     1.001000e+03
#
# [30264 rows x 1 columns]

# %%
# save top ten rows by streaming 
top_songs_2020 = songs_2020.head(10)

# print top ten
top_songs_2020.reset_index()
# Out:
#                               title  total streams
# 0                   Blinding Lights   1.634833e+09
# 1                      Dance Monkey   1.174788e+09
# 2             Roses - Imanbek Remix   1.002278e+09
# 3                   Don't Start Now   9.845018e+08
# 4                           The Box   9.639734e+08
# 5                           Falling   8.735978e+08
# 6      ROCKSTAR (feat. Roddy Ricch)   8.657024e+08
# 7                  Watermelon Sugar   7.987184e+08
# 8                 Someone You Loved   7.461562e+08
# 9  death bed (coffee for your head)   7.336765e+08

# %%
# save top 100 rows by streaming for further analysis section, must reset index for venn diagram to work 
top_songs_2020_ext = songs_2020.head(100).reset_index()
#print
len(top_songs_2020_ext.reset_index())
# Out:
# 100

# %%
#create datframe for US from this year 
df_US_2020 = regional_df[(regional_df["region"] == "United States") & (regional_df["date"] == 2020)]

#sort df by total streams 
songs_US_2020 = df_US_2020.sort_values('total streams', ascending = False)

#save top ten rows by streaming 
top_songs_US_2020 = songs_US_2020.head(10)

#print top ten
top_songs_US_2020
# Out:
#         date                            title          artist         region  \
# 300559  2020                          The Box     Roddy Ricch  United States
# 237940  2020                  Blinding Lights      The Weeknd  United States
# 238354  2020                  Blueberry Faygo       Lil Mosey  United States
# 286988  2020     ROCKSTAR (feat. Roddy Ricch)          DaBaby  United States
# 269526  2020       Life Is Good (feat. Drake)          Future  United States
# 242340  2020                          Circles     Post Malone  United States
# 287132  2020                          ROXANNE  Arizona Zervas  United States
# 306327  2020  WAP (feat. Megan Thee Stallion)         Cardi B  United States
# 307090  2020                 Watermelon Sugar    Harry Styles  United States
# 306431  2020                     WHATS POPPIN     Jack Harlow  United States
#
#         total streams
# 300559    400892436.0
# 237940    331037132.0
# 238354    272855565.0
# 286988    268822544.0
# 269526    240623838.0
# 242340    219423327.0
# 287132    202582156.0
# 306327    200800495.0
# 307090    200626866.0
# 306431    189004912.0

# %%
#save top 100 rows by streaming for further analysis section
top_songs_US_2020_ext = songs_US_2020.head(100)
len(top_songs_US_2020_ext)
# Out:
# 100

# %%
#merge the top ten US data frame with the top ten non-global data frame 
outer_merged20 = pd.merge(top_songs_2020, top_songs_US_2020, how="outer", on=["title"])
outer_merged20
# Out:
#                                title  total streams_x    date          artist  \
# 0                    Blinding Lights     1.634833e+09  2020.0      The Weeknd
# 1                       Dance Monkey     1.174788e+09     NaN             NaN
# 2              Roses - Imanbek Remix     1.002278e+09     NaN             NaN
# 3                    Don't Start Now     9.845018e+08     NaN             NaN
# 4                            The Box     9.639734e+08  2020.0     Roddy Ricch
# 5                            Falling     8.735978e+08     NaN             NaN
# 6       ROCKSTAR (feat. Roddy Ricch)     8.657024e+08  2020.0          DaBaby
# 7                   Watermelon Sugar     7.987184e+08  2020.0    Harry Styles
# 8                  Someone You Loved     7.461562e+08     NaN             NaN
# 9   death bed (coffee for your head)     7.336765e+08     NaN             NaN
# 10                   Blueberry Faygo              NaN  2020.0       Lil Mosey
# 11        Life Is Good (feat. Drake)              NaN  2020.0          Future
# 12                           Circles              NaN  2020.0     Post Malone
# 13                           ROXANNE              NaN  2020.0  Arizona Zervas
# 14   WAP (feat. Megan Thee Stallion)              NaN  2020.0         Cardi B
# 15                      WHATS POPPIN              NaN  2020.0     Jack Harlow
#
#            region  total streams_y
# 0   United States      331037132.0
# 1             NaN              NaN
# 2             NaN              NaN
# 3             NaN              NaN
# 4   United States      400892436.0
# 5             NaN              NaN
# 6   United States      268822544.0
# 7   United States      200626866.0
# 8             NaN              NaN
# 9             NaN              NaN
# 10  United States      272855565.0
# 11  United States      240623838.0
# 12  United States      219423327.0
# 13  United States      202582156.0
# 14  United States      200800495.0
# 15  United States      189004912.0

# %%
#create df for global vs us streams 
global_vs_us_2020 = pd.DataFrame({"Songs": outer_merged20["title"], "US Streams": outer_merged20["total streams_y"], "Global Streams": outer_merged20["total streams_x"]})

#reset df index
global_vs_us_2020 = global_vs_us_2020.groupby(['Songs']).first().reset_index()

#fill empty values with 0
global_vs_us_2020['Global Streams'] = global_vs_us_2020['Global Streams'].fillna(0)

#fill empty values with 0
global_vs_us_2020['US Streams'] = global_vs_us_2020['US Streams'].fillna(0)

#print df
global_vs_us_2020
# Out:
#                                Songs   US Streams  Global Streams
# 0                    Blinding Lights  331037132.0    1.634833e+09
# 1                    Blueberry Faygo  272855565.0    0.000000e+00
# 2                            Circles  219423327.0    0.000000e+00
# 3                       Dance Monkey          0.0    1.174788e+09
# 4                    Don't Start Now          0.0    9.845018e+08
# 5                            Falling          0.0    8.735978e+08
# 6         Life Is Good (feat. Drake)  240623838.0    0.000000e+00
# 7       ROCKSTAR (feat. Roddy Ricch)  268822544.0    8.657024e+08
# 8                            ROXANNE  202582156.0    0.000000e+00
# 9              Roses - Imanbek Remix          0.0    1.002278e+09
# 10                 Someone You Loved          0.0    7.461562e+08
# 11                           The Box  400892436.0    9.639734e+08
# 12   WAP (feat. Megan Thee Stallion)  200800495.0    0.000000e+00
# 13                      WHATS POPPIN  189004912.0    0.000000e+00
# 14                  Watermelon Sugar  200626866.0    7.987184e+08
# 15  death bed (coffee for your head)          0.0    7.336765e+08

# %%
#create x vaiable 
unique_top_songs = global_vs_us_2020["Songs"]

#define x variable
X = unique_top_songs

#define y variable #1
global_songs = global_vs_us_2020["Global Streams"]

#define y variable #2
us_songs = global_vs_us_2020["US Streams"]

#define length of x-axis
X_axis = np.arange(len(X))

#add colors 
color1 = "lightgreen"
color2 = "green"

#plot y variable #1
plt.bar(X_axis + 0.2, global_songs, 0.4, label = 'Global Songs', color=color1)

#plot y variable #2
plt.bar(X_axis - 0.2, us_songs, 0.4, label = 'US Songs', color=color2)

#plot x ticks
plt.xticks(X_axis, X)

#rotate x ticks
plt.xticks(rotation = 90)

#create labels 
plt.xlabel("Top Songs")
plt.ylabel("Total Streams (in billions)")

#create title 
plt.title("Global vs US Top Songs in 2020")

#plot legend 
plt.legend()

#export chart to pngs
plt.savefig("Global_vs_US_top_songs_2020.png")

#show plot
plt.show()

# %%
# find songs that appear on both top lists
both = global_vs_us_2020.loc[(global_vs_us_2020["US Streams"] > 0) & (global_vs_us_2020["Global Streams"] > 0)]       

# count number of songs  that appear on both top lists
US_song_count = both["Songs"].count()

# count number of songs on global top ten chart
song_count = len(top_songs_2020)

# find percent of US songs that appear in global top ten
song_percent_2020 = US_song_count/song_count * 100

# print findings 
print(f"The US charts had {song_percent_2020}% of the same top ten songs as the global charts in 2020.")
# Out:
# The US charts had 40.0% of the same top ten songs as the global charts in 2020.

# %% [markdown]
# Further analysis into the top 100 songs for 2020

# %%
# merge extended top song data frames for 2018 (top 100 US and top 100 non-global summed)
top100_merged20 = pd.merge(top_songs_2020_ext, top_songs_US_2020_ext, how="outer", on=["title"])
top100_merged20
# Out:
#                                                  title  total streams_x  \
# 0                                      Blinding Lights     1.634833e+09
# 1                                         Dance Monkey     1.174788e+09
# 2                                Roses - Imanbek Remix     1.002278e+09
# 3                                      Don't Start Now     9.845018e+08
# 4                                              The Box     9.639734e+08
# ..                                                 ...              ...
# 138                                              Myron              NaN
# 139                                               Suge              NaN
# 140                                        Sum 2 Prove              NaN
# 141  Hate The Other Side (with Marshmello & The Kid...              NaN
# 142                                             Ransom              NaN
#
#        date              artist         region  total streams_y
# 0    2020.0          The Weeknd  United States      331037132.0
# 1    2020.0         Tones And I  United States      151107412.0
# 2    2020.0           SAINt JHN  United States      172496651.0
# 3    2020.0            Dua Lipa  United States      179002480.0
# 4    2020.0         Roddy Ricch  United States      400892436.0
# ..      ...                 ...            ...              ...
# 138  2020.0        Lil Uzi Vert  United States       81140683.0
# 139  2020.0              DaBaby  United States       79186368.0
# 140  2020.0            Lil Baby  United States       79172412.0
# 141  2020.0  Juice WRLD, Polo G  United States       79118428.0
# 142  2020.0           Lil Tecca  United States       78543313.0
#
# [143 rows x 6 columns]

# %%
#create df for global vs us streams 
global_vs_us_2020 = pd.DataFrame({"Songs": top100_merged20["title"], "US Streams": top100_merged20["total streams_y"], "Global Streams": top100_merged20["total streams_x"]})

#reset df index
global_vs_us_2020 = global_vs_us_2020.groupby(['Songs']).first().reset_index()

#fill empty values with 0
global_vs_us_2020['Global Streams'] = global_vs_us_2020['Global Streams'].fillna(0)

#fill empty values with 0
global_vs_us_2020['US Streams'] = global_vs_us_2020['US Streams'].fillna(0)

#print df
global_vs_us_2020
# Out:
#                                  Songs   US Streams  Global Streams
# 0    10,000 Hours (with Justin Bieber)  102192286.0     241936743.0
# 1                            Adore You  175384087.0     524952313.0
# 2                          After Party  118482861.0             0.0
# 3               All Girls Are The Same  145489010.0             0.0
# 4                  Armed And Dangerous   81328671.0             0.0
# ..                                 ...          ...             ...
# 137               lovely (with Khalid)  104755992.0     298639315.0
# 138                          positions          0.0     307250238.0
# 139         rockstar (feat. 21 Savage)   83158826.0             0.0
# 140              when the party's over   89479687.0             0.0
# 141                 you broke me first          0.0     308887514.0
#
# [142 rows x 3 columns]

# %%
#find songs that appear on both top lists
both = global_vs_us_2020.loc[(global_vs_us_2020["US Streams"] > 0) & (global_vs_us_2020["Global Streams"] > 0)]       

#count number of songs  that appear on both top lists
US_song_count = both["Songs"].count()

#count number of songs on global top ten chart
song_count = len(top_songs_2020_ext)

#find percent of US songs that appear in global top ten
song_percent_2020 = US_song_count/song_count * 100

#print findings 
print(f"The US charts had {song_percent_2020}% of the same top 100 songs as the global charts in 2020.")
# Out:
# The US charts had 56.99999999999999% of the same top 100 songs as the global charts in 2020.

# %%
#create venn diagram
venn2([set(top_songs_US_2020_ext["title"]),
       set(top_songs_2020_ext["title"])],
       set_labels=('United States', 'Global'),
       set_colors=('green', 'silver'))

#export chart to pngs
plt.savefig("_top_songs_2020_venn.png")

# %% [markdown]
# Top Songs 2021

# %%
# create data frame that only includes songs and streaming information for 2018
df_2021 = regional_df[(regional_df["date"] == 2021)]
df_2021.head()
# Out:
#         date               title               artist    region  total streams
# 319124  2021                   !          Samey, Gleb  Slovakia         3581.0
# 319125  2021               "BOP"                   CJ   Finland         6516.0
# 319126  2021            #AiChoAi  Flo D, Giang Nguyễn   Vietnam       111969.0
# 319127  2021  #BrooklynBloodPop!                 SyKo   Estonia        40773.0
# 319128  2021  #BrooklynBloodPop!                 SyKo   Finland         7647.0

# %%
# double bracket to keep from changing to a series, this line also totals the non global streams for each song
songs_by_total_streams21=df_2021.groupby("title")[["total streams"]].sum()
songs_by_total_streams21
# Out:
#                                  total streams
# title
# !                                       3581.0
# "BOP"                                   6516.0
# #AiChoAi                              111969.0
# #BrooklynBloodPop!                   1586031.0
# #BrooklynBloodPop! - Roku Remix       257497.0
# ...                                        ...
# 우산 (feat. 윤하)                           1427.0
# 욱 (UGH!)                               43909.0
# 친구                                    356265.0
# 키스는 다음에                                93903.0
# 🪐                                      31970.0
#
# [30760 rows x 1 columns]

# %%
# sort dataframe of songs from this year by total streams in descending order 
songs_2021 = songs_by_total_streams21.sort_values('total streams', ascending = False)
songs_2021
# Out:
#                                    total streams
# title
# STAY (with Justin Bieber)           1.092135e+09
# drivers license                     1.091478e+09
# MONTERO (Call Me By Your Name)      1.083796e+09
# good 4 u                            1.058001e+09
# Levitating (feat. DaBaby)           9.049694e+08
# ...                                          ...
# Don't Dance 2.1                     1.003000e+03
# Los Estudiantes                     1.002000e+03
# Teic, Kur Zeme Tā                   1.002000e+03
# Divata                              1.002000e+03
# Brand New Guy (feat. ScHoolboy Q)   1.002000e+03
#
# [30760 rows x 1 columns]

# %%
# save top ten rows by streaming 
top_songs_2021 = songs_2021.head(10)

# print top ten
top_songs_2021.reset_index()
# Out:
#                                     title  total streams
# 0               STAY (with Justin Bieber)   1.092135e+09
# 1                         drivers license   1.091478e+09
# 2          MONTERO (Call Me By Your Name)   1.083796e+09
# 3                                good 4 u   1.058001e+09
# 4               Levitating (feat. DaBaby)   9.049694e+08
# 5  Peaches (feat. Daniel Caesar & Giveon)   8.804763e+08
# 6                Kiss Me More (feat. SZA)   8.568532e+08
# 7                         Blinding Lights   8.249933e+08
# 8       INDUSTRY BABY (feat. Jack Harlow)   7.712293e+08
# 9                                 Beggin'   7.587723e+08

# %%
# save top 100 rows by streaming for further analysis section, reset index function is needed for venn diagram
top_songs_2021_ext = songs_2021.head(100).reset_index()
#print
top_songs_2021_ext.reset_index()
# Out:
#     index                                  title  total streams
# 0       0              STAY (with Justin Bieber)   1.092135e+09
# 1       1                        drivers license   1.091478e+09
# 2       2         MONTERO (Call Me By Your Name)   1.083796e+09
# 3       3                               good 4 u   1.058001e+09
# 4       4              Levitating (feat. DaBaby)   9.049694e+08
# ..    ...                                    ...            ...
# 95     95                                Heather   2.046557e+08
# 96     96                    Permission to Dance   2.043920e+08
# 97     97                                Circles   2.032532e+08
# 98     98  Way 2 Sexy (with Future & Young Thug)   2.004756e+08
# 99     99               love nwantiti (ah ah ah)   1.998530e+08
#
# [100 rows x 3 columns]

# %%
#create datframe for US from this year 
df_US_2021 = regional_df[(regional_df["region"] == "United States") & (regional_df["date"] == 2021)]

#sort df by total streams 
songs_US_2021 = df_US_2021.sort_values('total streams', ascending = False)

#save top ten rows by streaming 
top_songs_US_2021 = songs_US_2021.head(10)

#print top ten
top_songs_US_2021
# Out:
#         date                              title          artist  \
# 397448  2021                           good 4 u  Olivia Rodrigo
# 396958  2021                    drivers license  Olivia Rodrigo
# 347346  2021                         Heat Waves   Glass Animals
# 354122  2021           Kiss Me More (feat. SZA)        Doja Cat
# 357418  2021          Levitating (feat. DaBaby)        Dua Lipa
# 360743  2021     MONTERO (Call Me By Your Name)       Lil Nas X
# 377469  2021          STAY (with Justin Bieber)   The Kid LAROI
# 373994  2021                            RAPSTAR          Polo G
# 350444  2021  INDUSTRY BABY (feat. Jack Harlow)       Lil Nas X
# 396854  2021                            deja vu  Olivia Rodrigo
#
#                region  total streams
# 397448  United States    316909493.0
# 396958  United States    306465075.0
# 347346  United States    274698424.0
# 354122  United States    268963860.0
# 357418  United States    259084916.0
# 360743  United States    249089858.0
# 377469  United States    241632288.0
# 373994  United States    222366492.0
# 350444  United States    217493707.0
# 396854  United States    213855457.0

# %%
#save top 100 rows by streaming for further analysis section
top_songs_US_2021_ext = songs_US_2021.head(100)
top_songs_US_2021_ext
# Out:
#         date                                    title  \
# 397448  2021                                 good 4 u
# 396958  2021                          drivers license
# 347346  2021                               Heat Waves
# 354122  2021                 Kiss Me More (feat. SZA)
# 357418  2021                Levitating (feat. DaBaby)
# ...      ...                                      ...
# 345512  2021                       Goosebumps - Remix
# 362388  2021                      Meet Me At Our Spot
# 385969  2021                                  The Box
# 398336  2021  m y . l i f e (with 21 Savage & Morray)
# 371547  2021                                    Pepas
#
#                                  artist         region  total streams
# 397448                   Olivia Rodrigo  United States    316909493.0
# 396958                   Olivia Rodrigo  United States    306465075.0
# 347346                    Glass Animals  United States    274698424.0
# 354122                         Doja Cat  United States    268963860.0
# 357418                         Dua Lipa  United States    259084916.0
# ...                                 ...            ...            ...
# 345512               Travis Scott, HVME  United States     75462580.0
# 362388  THE ANXIETY, WILLOW, Tyler Cole  United States     75047417.0
# 385969                      Roddy Ricch  United States     74404500.0
# 398336                          J. Cole  United States     74102036.0
# 371547                          Farruko  United States     72757914.0
#
# [100 rows x 5 columns]

# %%
#merge the top ten US data frame with the top ten non-global data frame 
outer_merged21 = pd.merge(top_songs_2021, top_songs_US_2021, how="outer", on=["title"])
outer_merged21
# Out:
#                                      title  total streams_x    date  \
# 0                STAY (with Justin Bieber)     1.092135e+09  2021.0
# 1                          drivers license     1.091478e+09  2021.0
# 2           MONTERO (Call Me By Your Name)     1.083796e+09  2021.0
# 3                                 good 4 u     1.058001e+09  2021.0
# 4                Levitating (feat. DaBaby)     9.049694e+08  2021.0
# 5   Peaches (feat. Daniel Caesar & Giveon)     8.804763e+08     NaN
# 6                 Kiss Me More (feat. SZA)     8.568532e+08  2021.0
# 7                          Blinding Lights     8.249933e+08     NaN
# 8        INDUSTRY BABY (feat. Jack Harlow)     7.712293e+08  2021.0
# 9                                  Beggin'     7.587723e+08     NaN
# 10                              Heat Waves              NaN  2021.0
# 11                                 RAPSTAR              NaN  2021.0
# 12                                 deja vu              NaN  2021.0
#
#             artist         region  total streams_y
# 0    The Kid LAROI  United States      241632288.0
# 1   Olivia Rodrigo  United States      306465075.0
# 2        Lil Nas X  United States      249089858.0
# 3   Olivia Rodrigo  United States      316909493.0
# 4         Dua Lipa  United States      259084916.0
# 5              NaN            NaN              NaN
# 6         Doja Cat  United States      268963860.0
# 7              NaN            NaN              NaN
# 8        Lil Nas X  United States      217493707.0
# 9              NaN            NaN              NaN
# 10   Glass Animals  United States      274698424.0
# 11          Polo G  United States      222366492.0
# 12  Olivia Rodrigo  United States      213855457.0

# %%
#create df for global vs us streams 
global_vs_us_2021 = pd.DataFrame({"Songs": outer_merged21["title"], "US Streams": outer_merged21["total streams_y"], "Global Streams": outer_merged21["total streams_x"]})

#reset df index
global_vs_us_2021 = global_vs_us_2021.groupby(['Songs']).first().reset_index()

#fill empty values with 0
global_vs_us_2021['Global Streams'] = global_vs_us_2021['Global Streams'].fillna(0)

#fill empty values with 0
global_vs_us_2021['US Streams'] = global_vs_us_2021['US Streams'].fillna(0)

#print df
global_vs_us_2021
# Out:
#                                      Songs   US Streams  Global Streams
# 0                                  Beggin'          0.0    7.587723e+08
# 1                          Blinding Lights          0.0    8.249933e+08
# 2                               Heat Waves  274698424.0    0.000000e+00
# 3        INDUSTRY BABY (feat. Jack Harlow)  217493707.0    7.712293e+08
# 4                 Kiss Me More (feat. SZA)  268963860.0    8.568532e+08
# 5                Levitating (feat. DaBaby)  259084916.0    9.049694e+08
# 6           MONTERO (Call Me By Your Name)  249089858.0    1.083796e+09
# 7   Peaches (feat. Daniel Caesar & Giveon)          0.0    8.804763e+08
# 8                                  RAPSTAR  222366492.0    0.000000e+00
# 9                STAY (with Justin Bieber)  241632288.0    1.092135e+09
# 10                                 deja vu  213855457.0    0.000000e+00
# 11                         drivers license  306465075.0    1.091478e+09
# 12                                good 4 u  316909493.0    1.058001e+09

# %%
#create x vaiable 
unique_top_songs = global_vs_us_2021["Songs"]

#define x variable
X = unique_top_songs

#define y variable #1
global_songs = global_vs_us_2021["Global Streams"]

#define y variable #2
us_songs = global_vs_us_2021["US Streams"]

#define length of x-axis
X_axis = np.arange(len(X))

#add colors 
color1 = "lightgreen"
color2 = "green"

#plot y variable #1
plt.bar(X_axis + 0.2, global_songs, 0.4, label = 'Global Songs', color=color1)

#plot y variable #2
plt.bar(X_axis - 0.2, us_songs, 0.4, label = 'US Songs', color=color2)

#plot x ticks
plt.xticks(X_axis, X)

#rotate x ticks
plt.xticks(rotation = 90)

#create labels 
plt.xlabel("Top Songs")
plt.ylabel("Total Streams (in billions)")

#create title 
plt.title("Global vs US Top Songs in 2021")

#plot legend 
plt.legend()

#export chart to pngs
plt.savefig("Global_vs_US_top_songs_2021.png")

#show plot
plt.show()

# %%
#find songs that appear on both top lists
both = global_vs_us_2021.loc[(global_vs_us_2021["US Streams"] > 0) & (global_vs_us_2021["Global Streams"] > 0)]       

#count number of songs  that appear on both top lists
US_song_count = both["Songs"].count()

#count number of songs on global top ten chart
song_count = len(top_songs_2021)

#find percent of US songs that appear in global top ten
song_percent_2021 = US_song_count/song_count * 100

#print findings 
print(f"The US charts had {song_percent_2021}% of the same top ten songs as the global charts in 2021.")
# Out:
# The US charts had 70.0% of the same top ten songs as the global charts in 2021.

# %% [markdown]
# Further analysis into the top 100 song in 2021

# %%
# merge extended top song data frames for 2018 (top 100 US and top 100 non-global summed)
top100_merged21 = pd.merge(top_songs_2021_ext, top_songs_US_2021_ext, how="outer", on=["title"])
top100_merged21
# Out:
#                                        title  total streams_x    date  \
# 0                  STAY (with Justin Bieber)     1.092135e+09  2021.0
# 1                            drivers license     1.091478e+09  2021.0
# 2             MONTERO (Call Me By Your Name)     1.083796e+09  2021.0
# 3                                   good 4 u     1.058001e+09  2021.0
# 4                  Levitating (feat. DaBaby)     9.049694e+08  2021.0
# ..                                       ...              ...     ...
# 139                                      505              NaN  2021.0
# 140                                Thot Shit              NaN  2021.0
# 141                      Meet Me At Our Spot              NaN  2021.0
# 142                                  The Box              NaN  2021.0
# 143  m y . l i f e (with 21 Savage & Morray)              NaN  2021.0
#
#                               artist         region  total streams_y
# 0                      The Kid LAROI  United States      241632288.0
# 1                     Olivia Rodrigo  United States      306465075.0
# 2                          Lil Nas X  United States      249089858.0
# 3                     Olivia Rodrigo  United States      316909493.0
# 4                           Dua Lipa  United States      259084916.0
# ..                               ...            ...              ...
# 139                   Arctic Monkeys  United States       76838609.0
# 140              Megan Thee Stallion  United States       75536523.0
# 141  THE ANXIETY, WILLOW, Tyler Cole  United States       75047417.0
# 142                      Roddy Ricch  United States       74404500.0
# 143                          J. Cole  United States       74102036.0
#
# [144 rows x 6 columns]

# %%
#create df for global vs us streams 
global_vs_us_2021 = pd.DataFrame({"Songs": top100_merged21["title"], "US Streams": top100_merged21["total streams_y"], "Global Streams": top100_merged21["total streams_x"]})

#reset df index
global_vs_us_2021 = global_vs_us_2021.groupby(['Songs']).first().reset_index()

#fill empty values with 0
global_vs_us_2021['Global Streams'] = global_vs_us_2021['Global Streams'].fillna(0)

#fill empty values with 0
global_vs_us_2021['US Streams'] = global_vs_us_2021['US Streams'].fillna(0)

#print df
global_vs_us_2021
# Out:
#                                     Songs   US Streams  Global Streams
# 0                               2/Catorce          0.0     218932348.0
# 1                                  20 Min   98100970.0             0.0
# 2                                    2055  103181086.0             0.0
# 3                                   34+35   92195147.0     259726970.0
# 4                                     505   76838609.0             0.0
# ..                                    ...          ...             ...
# 139  my ex's best friend (with blackbear)  131258025.0             0.0
# 140                             positions   94432999.0     359710419.0
# 141                             telepatía  145027902.0     425455739.0
# 142                               traitor  167545529.0     473398539.0
# 143                    you broke me first   92882711.0     296001663.0
#
# [144 rows x 3 columns]

# %%
#find songs that appear on both top lists
both = global_vs_us_2021.loc[(global_vs_us_2019["US Streams"] > 0) & (global_vs_us_2021["Global Streams"] > 0)]       

#count number of songs  that appear on both top lists
US_song_count = both["Songs"].count()

#count number of songs on global top ten chart
song_count = len(top_songs_2021_ext)

#find percent of US songs that appear in global top ten
song_percent_2021 = US_song_count/song_count * 100

#print findings 
print(f"The US charts had {song_percent_2021}% of the same top 100 songs as the global charts in 2021.")
# Out:
# The US charts had 66.0% of the same top 100 songs as the global charts in 2021.

# %%
#create venn diagram
venn2([set(top_songs_US_2021_ext["title"]),
       set(top_songs_2021_ext["title"])],
       set_labels=('United States', 'Global'),
       set_colors=('green', 'silver'))

#export chart to pngs
plt.savefig("_top_songs_2021_venn.png")

# %% [markdown]
# Top Songs Overall 2017-2021

# %%
#create datframe 
df_overall = regional_df

# double bracket to keep from changing to a series, this line also totals the non global streams for each song
songs_overall=df_overall.groupby("title")[["total streams"]].sum()

#print
songs_overall
# Out:
#                                            total streams
# title
# !                                              3790809.0
# !I'll Be Back!                                   36343.0
# "42" - From SR3MM                               297731.0
# "All That Is or Ever Was or Ever Will Be"         7311.0
# "BOP"                                             6516.0
# ...                                                  ...
# 피 땀 눈물                                           70997.0
# 항상 (HANGSANG)                                   141250.0
# 해와 달처럼 Day and Night                             74178.0
# 혼자 Nobody knows                                   6416.0
# 🪐                                                31970.0
#
# [91213 rows x 1 columns]

# %%
#sort df by total streams 
sorted_songs_overall = songs_overall.sort_values('total streams', ascending = False)

#save top ten rows by streaming 
top_songs_overall = sorted_songs_overall.head(10)

#print top ten
top_songs_overall = top_songs_overall.reset_index()
top_songs_overall
# Out:
#                                            title  total streams
# 0                                Blinding Lights   2.559543e+09
# 1                                   Shape of You   2.324246e+09
# 2                                   Dance Monkey   2.179513e+09
# 3                              Someone You Loved   1.888980e+09
# 4  Sunflower - Spider-Man: Into the Spider-Verse   1.740188e+09
# 5                                       Señorita   1.644427e+09
# 6                                        bad guy   1.586601e+09
# 7                                Don't Start Now   1.543022e+09
# 8                                   Lucid Dreams   1.456142e+09
# 9                                        Happier   1.412915e+09

# %%
#save top 100 rows by streaming 
top_songs_overall_ext = sorted_songs_overall.head(100).reset_index()
top_songs_overall_ext
# Out:
#                                             title  total streams
# 0                                 Blinding Lights   2.559543e+09
# 1                                    Shape of You   2.324246e+09
# 2                                    Dance Monkey   2.179513e+09
# 3                               Someone You Loved   1.888980e+09
# 4   Sunflower - Spider-Man: Into the Spider-Verse   1.740188e+09
# ..                                            ...            ...
# 95       Meant to Be (feat. Florida Georgia Line)   6.599229e+08
# 96                                     In My Mind   6.521194e+08
# 97                                          IDGAF   6.489980e+08
# 98                                  Calma - Remix   6.449158e+08
# 99                             That's What I Like   6.446990e+08
#
# [100 rows x 2 columns]

# %%
#create datframe for US overall
df_US_overall = regional_df[regional_df["region"] == "United States"]

# double bracket to keep from changing to a series, this line also totals the non global streams for each song
songs_overall_US=df_US_overall.groupby("title")[["total streams"]].sum()

#print
len(songs_overall_US)
# Out:
# 7543

# %%
#sort df by total streams 
sorted_songs_US = songs_overall_US.sort_values('total streams', ascending = False)

#save top ten rows by streaming 
top_songs_US_overall = sorted_songs_US.head(10)

#print top ten
top_songs_US_overall=top_songs_US_overall.reset_index()
top_songs_US_overall
# Out:
#                                            title  total streams
# 0  Sunflower - Spider-Man: Into the Spider-Verse    778581058.0
# 1                                   Lucid Dreams    769070890.0
# 2                                     goosebumps    624010649.0
# 3                                           SAD!    617887484.0
# 4                                 Jocelyn Flores    598009402.0
# 5                                     SICKO MODE    586638599.0
# 6                                        HUMBLE.    549292830.0
# 7                                  XO Tour Llif3    541785400.0
# 8                                   I Fall Apart    541736865.0
# 9                                Blinding Lights    536926299.0

# %%
#save top 100 rows by streaming 
top_songs_US_overall_ext = sorted_songs_US.head(100).reset_index()
len(top_songs_US_overall_ext)
# Out:
# 100

# %%
# perform outer merge to include US streams and the sum of non global streams for each song
top10_merged = pd.merge(top_songs_overall, top_songs_US_overall, how="outer", on=["title"])
top10_merged=top10_merged.reset_index()
len(top10_merged)
# Out:
# 17

# %%
#create df for global vs us streams 
global_vs_us = pd.DataFrame({"Songs": top10_merged["title"], "US Streams": top10_merged["total streams_y"], "Global Streams": top10_merged["total streams_x"]})

#reset df index
global_vs_us = global_vs_us.groupby(['Songs']).first().reset_index()

#fill empty values with 0
global_vs_us['Global Streams'] = global_vs_us['Global Streams'].fillna(0)

#fill empty values with 0
global_vs_us['US Streams'] = global_vs_us['US Streams'].fillna(0)

#print df
global_vs_us
# Out:
#                                             Songs   US Streams  Global Streams
# 0                                 Blinding Lights  536926299.0    2.559543e+09
# 1                                    Dance Monkey          0.0    2.179513e+09
# 2                                 Don't Start Now          0.0    1.543022e+09
# 3                                         HUMBLE.  549292830.0    0.000000e+00
# 4                                         Happier          0.0    1.412915e+09
# 5                                    I Fall Apart  541736865.0    0.000000e+00
# 6                                  Jocelyn Flores  598009402.0    0.000000e+00
# 7                                    Lucid Dreams  769070890.0    1.456142e+09
# 8                                            SAD!  617887484.0    0.000000e+00
# 9                                      SICKO MODE  586638599.0    0.000000e+00
# 10                                       Señorita          0.0    1.644427e+09
# 11                                   Shape of You          0.0    2.324246e+09
# 12                              Someone You Loved          0.0    1.888980e+09
# 13  Sunflower - Spider-Man: Into the Spider-Verse  778581058.0    1.740188e+09
# 14                                  XO Tour Llif3  541785400.0    0.000000e+00
# 15                                        bad guy          0.0    1.586601e+09
# 16                                     goosebumps  624010649.0    0.000000e+00

# %%
#create x variable 
unique_top_songs = global_vs_us["Songs"]

#define x variable
X = unique_top_songs

#define y variable #1
global_songs = global_vs_us["Global Streams"]

#define y variable #2
us_songs = global_vs_us["US Streams"]

#define length of x-axis
X_axis = np.arange(len(X))

#add colors 
color1 = "lightgreen"
color2 = "green"

#plot y variable #1
plt.bar(X_axis - 0.2, global_songs, 0.4, label = 'Global Songs', color=color1)

#plot y variable #2
plt.bar(X_axis + 0.2, us_songs, 0.4, label = 'US Songs', color=color2)

#plot x ticks
plt.xticks(X_axis, X)

#rotate x ticks
plt.xticks(rotation = 90)

#create labels 
plt.xlabel("Top Songs")
plt.ylabel("Total Streams (in billions)")

#create title 
plt.title("Global vs US Top Songs 2017-2021")

#plot legend 
plt.legend()

#export chart to pngs
plt.savefig("Global_vs_US_top_songs_overall.png")

#show plot
plt.show()

# %%
#find songs that appear on both top lists
both = global_vs_us.loc[(global_vs_us["US Streams"] > 0) & (global_vs_us["Global Streams"] > 0)]       

#count number of songs  that appear on both top lists
US_song_count = both["Songs"].count()

#count number of songs on global top ten chart
song_count = len(top_songs_US_overall)

#find percent of US songs that appear in global top ten
song_percent_overall = US_song_count/song_count * 100

#print findings 
print(f"The US charts had {song_percent_overall}% of the same top ten songs as the global charts 2017-2021.")
# Out:
# The US charts had 30.0% of the same top ten songs as the global charts 2017-2021.

# %%
# merge extended top song data frames for 2018 (top 100 US and top 100 non-global summed)
top100_merged_overall = pd.merge(top_songs_overall_ext, top_songs_US_overall_ext, how="outer", on=["title"])
top100_merged_overall
# Out:
#                                              title  total streams_x  \
# 0                                  Blinding Lights     2.559543e+09
# 1                                     Shape of You     2.324246e+09
# 2                                     Dance Monkey     2.179513e+09
# 3                                Someone You Loved     1.888980e+09
# 4    Sunflower - Spider-Man: Into the Spider-Verse     1.740188e+09
# ..                                             ...              ...
# 139                          Body Like A Back Road              NaN
# 140                                   Wishing Well              NaN
# 141                    Come & Go (with Marshmello)              NaN
# 142                        iSpy (feat. Lil Yachty)              NaN
# 143                       Pop Out (feat. Lil Tjay)              NaN
#
#      total streams_y
# 0        536926299.0
# 1        346307680.0
# 2        256274759.0
# 3        408581521.0
# 4        778581058.0
# ..               ...
# 139      257480631.0
# 140      257015513.0
# 141      254932712.0
# 142      254921525.0
# 143      251658876.0
#
# [144 rows x 3 columns]

# %%
#create df for global vs us streams 
global_vs_us_ext = pd.DataFrame({"Songs": top100_merged_overall["title"], "US Streams": top100_merged_overall["total streams_y"], "Global Streams": top100_merged21["total streams_x"]})

#reset df index
global_vs_us_ext = global_vs_us_ext.groupby(['Songs']).first().reset_index()

#fill empty values with 0
global_vs_us_ext['Global Streams'] = global_vs_us_ext['Global Streams'].fillna(0)

#fill empty values with 0
global_vs_us_ext['US Streams'] = global_vs_us_ext['US Streams'].fillna(0)

#print df
global_vs_us_ext
# Out:
#                           Songs   US Streams  Global Streams
# 0                1-800-273-8255  319116790.0             0.0
# 1                          2002          0.0     218932348.0
# 2                       7 rings  332694161.0     466295823.0
# 3                     Adore You          0.0     224130599.0
# 4        All Girls Are The Same  519965548.0             0.0
# ..                          ...          ...             ...
# 139                   positions          0.0     206448133.0
# 140                    rockstar  338333763.0     345005928.0
# 141  rockstar (feat. 21 Savage)  380313220.0     287117096.0
# 142               thank u, next  317987550.0     344813884.0
# 143       when the party's over  331192577.0     258311314.0
#
# [144 rows x 3 columns]

# %%
#find songs that appear on both top lists
both = global_vs_us_ext.loc[(global_vs_us_ext["US Streams"] > 0) & (global_vs_us_ext["Global Streams"] > 0)]       

#count number of songs  that appear on both top lists
US_song_count = both["Songs"].count()
US_song_count
# Out:
# 56

# %%
#count number of songs on global top ten chart
song_count = len(top_songs_overall_ext)

#find percent of US songs that appear in global top ten
song_percent_ext = US_song_count/song_count * 100

#print findings 
print(f"The US charts had {song_percent_ext}% of the same top 100 songs as the global charts for 2017-2021.")
# Out:
# The US charts had 56.00000000000001% of the same top 100 songs as the global charts for 2017-2021.

# %%
#create venn diagram 
venn2([set(top_songs_US_overall_ext["title"]),
       set(top_songs_overall_ext["title"])],
       set_labels=('United States', 'Global'),
       set_colors=('green', 'silver'))

#export chart to pngs
plt.savefig("top_songs_overall_venn.png")

# %% [markdown]
# Country Contribution to the Top Song from Each Year Analysis

# %%
# create ne data frame that only includes songs and streaming data from 2017
df_2017_all = chart_data[(chart_data["date"] == 2017)]

# sort data frame by total streams to determine the most popular song from this year
all_songs_2017 = df_2017_all.sort_values('total streams', ascending = False)

all_songs_2017
# Out:
#        date                                  title  \
# 48188  2017                           Shape of You
# 12958  2017                      Despacito - Remix
# 12901  2017     Despacito (Featuring Daddy Yankee)
# 50763  2017               Something Just Like This
# 20887  2017                                HUMBLE.
# ...     ...                                    ...
# 36319  2017          Muy Personal (feat. J Balvin)
# 9634   2017                Chantaje (feat. Maluma)
# 35602  2017                        Mit Mondjak Még
# 4270   2017                Baby, You Make Me Crazy
# 40968  2017  Pa Que Me Invitan - Spanglish Version
#
#                                         artist       region  total streams
# 48188                               Ed Sheeran       Global   1.479857e+09
# 12958  Luis Fonsi, Daddy Yankee, Justin Bieber       Global   9.085726e+08
# 12901                               Luis Fonsi       Global   7.391564e+08
# 50763               The Chainsmokers, Coldplay       Global   6.864717e+08
# 20887                           Kendrick Lamar       Global   6.504118e+08
# ...                                        ...          ...            ...
# 36319                                   Yandel       Panama   1.001000e+03
# 9634                                   Shakira   Luxembourg   1.001000e+03
# 35602                      Kowalsky Meg A Vega      Hungary   1.001000e+03
# 4270                                 Sam Smith      Hungary   1.001000e+03
# 40968                  JENCARLOS, Charly Black  El Salvador   1.001000e+03
#
# [66579 rows x 5 columns]

# %%
# create df for the most streamed song from this year sorted by top contributing regions (excluding global)
shape_of_you = all_songs_2017[(all_songs_2017["title"] == "Shape of You") & (chart_data["region"] != "Global")]
shape_of_you
# Out:
# /var/folders/bp/kkf4c1nj557c5frmyn420c7c0000gn/T/ipykernel_49365/3343112863.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   shape_of_you = all_songs_2017[(all_songs_2017["title"] == "Shape of You") & (chart_data["region"] != "Global")]
#        date         title      artist              region  total streams
# 48223  2017  Shape of You  Ed Sheeran       United States    278916058.0
# 48222  2017  Shape of You  Ed Sheeran      United Kingdom    130658891.0
# 48187  2017  Shape of You  Ed Sheeran             Germany     96505235.0
# 48173  2017  Shape of You  Ed Sheeran              Brazil     95996545.0
# 48203  2017  Shape of You  Ed Sheeran              Mexico     86326454.0
# 48217  2017  Shape of You  Ed Sheeran              Sweden     63184448.0
# 48216  2017  Shape of You  Ed Sheeran               Spain     60057135.0
# 48211  2017  Shape of You  Ed Sheeran         Philippines     57245668.0
# 48204  2017  Shape of You  Ed Sheeran         Netherlands     55204354.0
# 48169  2017  Shape of You  Ed Sheeran           Australia     51174073.0
# 48175  2017  Shape of You  Ed Sheeran              Canada     47342929.0
# 48186  2017  Shape of You  Ed Sheeran              France     45572861.0
# 48168  2017  Shape of You  Ed Sheeran           Argentina     41015620.0
# 48197  2017  Shape of You  Ed Sheeran               Italy     37756493.0
# 48207  2017  Shape of You  Ed Sheeran              Norway     30840421.0
# 48176  2017  Shape of You  Ed Sheeran               Chile     29135735.0
# 48180  2017  Shape of You  Ed Sheeran             Denmark     24204277.0
# 48195  2017  Shape of You  Ed Sheeran           Indonesia     21158042.0
# 48221  2017  Shape of You  Ed Sheeran              Turkey     18171401.0
# 48212  2017  Shape of You  Ed Sheeran              Poland     16502838.0
# 48210  2017  Shape of You  Ed Sheeran                Peru     15918424.0
# 48214  2017  Shape of You  Ed Sheeran           Singapore     15459198.0
# 48185  2017  Shape of You  Ed Sheeran             Finland     15308400.0
# 48177  2017  Shape of You  Ed Sheeran            Colombia     14617209.0
# 48205  2017  Shape of You  Ed Sheeran         New Zealand     13059747.0
# 48202  2017  Shape of You  Ed Sheeran            Malaysia     11773514.0
# 48196  2017  Shape of You  Ed Sheeran             Ireland     11338765.0
# 48171  2017  Shape of You  Ed Sheeran             Belgium     11100581.0
# 48218  2017  Shape of You  Ed Sheeran         Switzerland      9784521.0
# 48213  2017  Shape of You  Ed Sheeran            Portugal      8498431.0
# 48219  2017  Shape of You  Ed Sheeran              Taiwan      7634560.0
# 48178  2017  Shape of You  Ed Sheeran          Costa Rica      7254643.0
# 48198  2017  Shape of You  Ed Sheeran               Japan      6481322.0
# 48170  2017  Shape of You  Ed Sheeran             Austria      5657482.0
# 48182  2017  Shape of You  Ed Sheeran             Ecuador      5185044.0
# 48192  2017  Shape of You  Ed Sheeran           Hong Kong      4960383.0
# 48179  2017  Shape of You  Ed Sheeran      Czech Republic      4248621.0
# 48193  2017  Shape of You  Ed Sheeran             Hungary      3479411.0
# 48224  2017  Shape of You  Ed Sheeran             Uruguay      2794561.0
# 48209  2017  Shape of You  Ed Sheeran            Paraguay      2408534.0
# 48190  2017  Shape of You  Ed Sheeran           Guatemala      2272532.0
# 48208  2017  Shape of You  Ed Sheeran              Panama      2080010.0
# 48181  2017  Shape of You  Ed Sheeran  Dominican Republic      2016652.0
# 48172  2017  Shape of You  Ed Sheeran             Bolivia      1837936.0
# 48191  2017  Shape of You  Ed Sheeran            Honduras      1768658.0
# 48189  2017  Shape of You  Ed Sheeran              Greece      1729758.0
# 48183  2017  Shape of You  Ed Sheeran         El Salvador      1546445.0
# 48194  2017  Shape of You  Ed Sheeran             Iceland      1473903.0
# 48215  2017  Shape of You  Ed Sheeran            Slovakia      1250326.0
# 48200  2017  Shape of You  Ed Sheeran           Lithuania       900862.0
# 48199  2017  Shape of You  Ed Sheeran              Latvia       878169.0
# 48184  2017  Shape of You  Ed Sheeran             Estonia       870791.0
# 48220  2017  Shape of You  Ed Sheeran            Thailand       687869.0
# 48174  2017  Shape of You  Ed Sheeran            Bulgaria       638659.0
# 48206  2017  Shape of You  Ed Sheeran           Nicaragua       581193.0
# 48201  2017  Shape of You  Ed Sheeran          Luxembourg       544631.0

# %%
# check your work, if correct should be less than or equal to 68 (total number of regions in original data frame)
len(shape_of_you)
# Out:
# 56

# %%
# truncate the data frame to only include the top ten countries by stream contribution for this song
shape_top = shape_of_you.head(10)
shape_top
# Out:
#        date         title      artist          region  total streams
# 48223  2017  Shape of You  Ed Sheeran   United States    278916058.0
# 48222  2017  Shape of You  Ed Sheeran  United Kingdom    130658891.0
# 48187  2017  Shape of You  Ed Sheeran         Germany     96505235.0
# 48173  2017  Shape of You  Ed Sheeran          Brazil     95996545.0
# 48203  2017  Shape of You  Ed Sheeran          Mexico     86326454.0
# 48217  2017  Shape of You  Ed Sheeran          Sweden     63184448.0
# 48216  2017  Shape of You  Ed Sheeran           Spain     60057135.0
# 48211  2017  Shape of You  Ed Sheeran     Philippines     57245668.0
# 48204  2017  Shape of You  Ed Sheeran     Netherlands     55204354.0
# 48169  2017  Shape of You  Ed Sheeran       Australia     51174073.0

# %%
# create bar plot to better visualize each country's contribution 
shape_bar = shape_top.plot.bar(x='region', y='total streams', figsize=(5, 5), width=.5, alpha=1, align="center", color = "lightgreen")

# add title
plt.title("Shape of You: Top Regions (2017)")

# label xaxis
plt.xlabel("Country")

# lable yaxis
plt.ylabel("Streams (hundred millions)")

# adjust graph layout 
plt.tight_layout()

# export chart to pngs
plt.savefig("Shape_Top_Ten_Countries.png")

# show graph 
plt.show()

# %%
# create venn diagram for easier visual analysis
venn2([set(top_ten.index), 
       set(shape_top['region'].to_list())],
       set_labels=('Global', 'Shape of You'),
       set_colors=('lightgreen', 'green'),
     )

# %%
# create ne data frame that only includes songs and streaming data from 2018
all_songs_18 = chart_data[(chart_data["date"] == 2018)]

# sort data frame by total streams to determine the most popular song from this year
top_songs_18 = all_songs_18.sort_values('total streams', ascending = False)

top_songs_18
# Out:
#         date                         title                        artist  \
# 91525   2018                    God's Plan                         Drake
# 122797  2018                          SAD!                  XXXTENTACION
# 119406  2018  Psycho (feat. Ty Dolla $ign)                   Post Malone
# 98407   2018                In My Feelings                         Drake
# 74624   2018                    Better Now                   Post Malone
# ...      ...                           ...                           ...
# 127129  2018                         Slide                     James Bay
# 130696  2018           Sweet Child O' Mine                 Guns N' Roses
# 134481  2018                Through It All                  Charlie Puth
# 91285   2018                        Glitch  Martin Garrix, Julian Jordan
# 104489  2018                           Lie                            NF
#
#           region  total streams
# 91525     Global   1.126032e+09
# 122797    Global   7.640701e+08
# 119406    Global   7.023187e+08
# 98407     Global   7.021119e+08
# 74624     Global   6.860381e+08
# ...          ...            ...
# 127129  Slovakia   1.001000e+03
# 130696  Honduras   1.001000e+03
# 134481   Vietnam   1.001000e+03
# 91285    Estonia   1.001000e+03
# 104489   Romania   1.001000e+03
#
# [82649 rows x 5 columns]

# %%
# create df for the most streamed song from this year sorted by top contributing regions (excluding global)
gods_plan = top_songs_18[(top_songs_18["title"] == "God's Plan") & (chart_data["region"] != "Global")]
gods_plan
# Out:
# /var/folders/bp/kkf4c1nj557c5frmyn420c7c0000gn/T/ipykernel_49365/204006112.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   gods_plan = top_songs_18[(top_songs_18["title"] == "God's Plan") & (chart_data["region"] != "Global")]
#        date       title artist              region  total streams
# 91563  2018  God's Plan  Drake       United States    453226629.0
# 91562  2018  God's Plan  Drake      United Kingdom     98750702.0
# 91512  2018  God's Plan  Drake              Canada     55809118.0
# 91524  2018  God's Plan  Drake             Germany     51393253.0
# 91506  2018  God's Plan  Drake           Australia     48905021.0
# 91510  2018  God's Plan  Drake              Brazil     45265461.0
# 91541  2018  God's Plan  Drake              Mexico     44443961.0
# 91542  2018  God's Plan  Drake         Netherlands     33744946.0
# 91523  2018  God's Plan  Drake              France     27576637.0
# 91557  2018  God's Plan  Drake              Sweden     27111313.0
# 91535  2018  God's Plan  Drake               Italy     27079280.0
# 91556  2018  God's Plan  Drake               Spain     21327543.0
# 91545  2018  God's Plan  Drake              Norway     14512048.0
# 91549  2018  God's Plan  Drake         Philippines     14505005.0
# 91517  2018  God's Plan  Drake             Denmark     12036766.0
# 91561  2018  God's Plan  Drake              Turkey      9886629.0
# 91543  2018  God's Plan  Drake         New Zealand      9793465.0
# 91533  2018  God's Plan  Drake             Ireland      8673055.0
# 91505  2018  God's Plan  Drake           Argentina      8030662.0
# 91532  2018  God's Plan  Drake           Indonesia      7807254.0
# 91513  2018  God's Plan  Drake               Chile      7325105.0
# 91508  2018  God's Plan  Drake             Belgium      7261727.0
# 91522  2018  God's Plan  Drake             Finland      6094503.0
# 91558  2018  God's Plan  Drake         Switzerland      5704185.0
# 91551  2018  God's Plan  Drake            Portugal      5505314.0
# 91550  2018  God's Plan  Drake              Poland      5256194.0
# 91553  2018  God's Plan  Drake           Singapore      5049988.0
# 91514  2018  God's Plan  Drake            Colombia      4518627.0
# 91540  2018  God's Plan  Drake            Malaysia      4406364.0
# 91507  2018  God's Plan  Drake             Austria      3196504.0
# 91515  2018  God's Plan  Drake          Costa Rica      3058868.0
# 91548  2018  God's Plan  Drake                Peru      2587017.0
# 91536  2018  God's Plan  Drake               Japan      2092424.0
# 91516  2018  God's Plan  Drake      Czech Republic      1644575.0
# 91529  2018  God's Plan  Drake           Hong Kong      1629557.0
# 91559  2018  God's Plan  Drake              Taiwan      1604821.0
# 91518  2018  God's Plan  Drake  Dominican Republic      1510226.0
# 91526  2018  God's Plan  Drake              Greece      1449111.0
# 91530  2018  God's Plan  Drake             Hungary      1334169.0
# 91527  2018  God's Plan  Drake           Guatemala      1250905.0
# 91519  2018  God's Plan  Drake             Ecuador      1240078.0
# 91546  2018  God's Plan  Drake              Panama      1225969.0
# 91531  2018  God's Plan  Drake             Iceland      1113396.0
# 91547  2018  God's Plan  Drake            Paraguay      1103647.0
# 91534  2018  God's Plan  Drake              Israel      1022602.0
# 91528  2018  God's Plan  Drake            Honduras       980188.0
# 91560  2018  God's Plan  Drake            Thailand       918743.0
# 91520  2018  God's Plan  Drake         El Salvador       908670.0
# 91552  2018  God's Plan  Drake             Romania       753241.0
# 91554  2018  God's Plan  Drake            Slovakia       620052.0
# 91537  2018  God's Plan  Drake              Latvia       585083.0
# 91509  2018  God's Plan  Drake             Bolivia       562107.0
# 91564  2018  God's Plan  Drake             Uruguay       454985.0
# 91555  2018  God's Plan  Drake        South Africa       365725.0
# 91538  2018  God's Plan  Drake           Lithuania       261108.0
# 91521  2018  God's Plan  Drake             Estonia       246672.0
# 91565  2018  God's Plan  Drake             Vietnam       134063.0
# 91511  2018  God's Plan  Drake            Bulgaria         4516.0
# 91544  2018  God's Plan  Drake           Nicaragua         3851.0
# 91539  2018  God's Plan  Drake          Luxembourg         2614.0

# %%
# check your work, if correct should be less than or equal to 68 
len(gods_plan)
# Out:
# 60

# %%
# truncate the data frame to only include the top ten countries by stream contribution for this song
gp_top = gods_plan.head(10)
gp_top
# Out:
#        date       title artist          region  total streams
# 91563  2018  God's Plan  Drake   United States    453226629.0
# 91562  2018  God's Plan  Drake  United Kingdom     98750702.0
# 91512  2018  God's Plan  Drake          Canada     55809118.0
# 91524  2018  God's Plan  Drake         Germany     51393253.0
# 91506  2018  God's Plan  Drake       Australia     48905021.0
# 91510  2018  God's Plan  Drake          Brazil     45265461.0
# 91541  2018  God's Plan  Drake          Mexico     44443961.0
# 91542  2018  God's Plan  Drake     Netherlands     33744946.0
# 91523  2018  God's Plan  Drake          France     27576637.0
# 91557  2018  God's Plan  Drake          Sweden     27111313.0

# %%
# create bar plot to better visualize each of the top ten country's contribution 
gp_bar = gp_top.plot.bar(x='region', y='total streams', figsize=(5, 5), width=.5, alpha=1, align="center", color = "lightgreen")

# add title
plt.title("God's Plan: Top Regions (2018)")

# label xaxis
plt.xlabel("Country")

# lable yaxis
plt.ylabel("Streams (hundred millions)")

# adjust graph layout 
plt.tight_layout()

# export chart to pngs
plt.savefig("gods_plan_top ten_countries.png")

# show graph 
plt.show()

# %%
# create a venn diagram to show how many of the overall top contries contributed to this song 
venn2([set(top_ten.index), 
       set(gp_top['region'].to_list())],
       set_labels=('Global', "God's Plan"),
       set_colors=('lightgreen', 'green'),
     )

# %%
# filter data frame to only display songs from 2019
all_songs_2019 = chart_data[(chart_data["date"] == 2019)]

# sort dataframe by total streams (in descending order) to determine the most popular song from this year 
sorted_songs_2019 = all_songs_2019.sort_values('total streams', ascending = False)

sorted_songs_2019
# Out:
#         date                                          title  \
# 206911  2019                                       Señorita
# 222870  2019                                        bad guy
# 211012  2019  Sunflower - Spider-Man: Into the Spider-Verse
# 150418  2019                                        7 rings
# 209271  2019                              Someone You Loved
# ...      ...                                            ...
# 206266  2019                            Scared to Be Lonely
# 178455  2019                               I Think He Knows
# 201530  2019                                         Putana
# 161408  2019                          Clout (feat. Cardi B)
# 223503  2019                                       comethru
#
#                               artist        region  total streams
# 206911  Shawn Mendes, Camila Cabello        Global   1.070268e+09
# 222870                 Billie Eilish        Global   1.052359e+09
# 211012         Post Malone, Swae Lee        Global   9.869068e+08
# 150418                 Ariana Grande        Global   9.613615e+08
# 209271                 Lewis Capaldi        Global   8.237803e+08
# ...                              ...           ...            ...
# 206266       Martin Garrix, Dua Lipa  Saudi Arabia   1.001000e+03
# 178455                  Taylor Swift        Latvia   1.001000e+03
# 201530                         Ninho       Morocco   1.001000e+03
# 161408                        Offset        Latvia   1.001000e+03
# 223503                 Jeremy Zucker  South Africa   1.001000e+03
#
# [79202 rows x 5 columns]

# %%
# create df for the most streamed song from this year sorted by top contributing regions (excluding global)
señorita = sorted_songs_2019[(sorted_songs_2019["title"] == "Señorita") & (chart_data["artist"] == "Shawn Mendes, Camila Cabello") & (chart_data["region"] != "Global")]
# this year had multiple songs named "señorita" so an extra filter for artist had to be added above 
señorita
# Out:
# /var/folders/bp/kkf4c1nj557c5frmyn420c7c0000gn/T/ipykernel_49365/3085146009.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   señorita = sorted_songs_2019[(sorted_songs_2019["title"] == "Señorita") & (chart_data["artist"] == "Shawn Mendes, Camila Cabello") & (chart_data["region"] != "Global")]
#         date     title                        artist          region  \
# 206953  2019  Señorita  Shawn Mendes, Camila Cabello   United States
# 206910  2019  Señorita  Shawn Mendes, Camila Cabello         Germany
# 206928  2019  Señorita  Shawn Mendes, Camila Cabello          Mexico
# 206952  2019  Señorita  Shawn Mendes, Camila Cabello  United Kingdom
# 206895  2019  Señorita  Shawn Mendes, Camila Cabello          Brazil
# ...      ...       ...                           ...             ...
# 206896  2019  Señorita  Shawn Mendes, Camila Cabello        Bulgaria
# 206929  2019  Señorita  Shawn Mendes, Camila Cabello         Morocco
# 206932  2019  Señorita  Shawn Mendes, Camila Cabello       Nicaragua
# 206905  2019  Señorita  Shawn Mendes, Camila Cabello           Egypt
# 206926  2019  Señorita  Shawn Mendes, Camila Cabello      Luxembourg
#
#         total streams
# 206953    178554964.0
# 206910     68105088.0
# 206928     64803176.0
# 206952     57663930.0
# 206895     57029178.0
# ...               ...
# 206896       584978.0
# 206929       452441.0
# 206932       405426.0
# 206905       227496.0
# 206926        46837.0
#
# [65 rows x 5 columns]

# %%
# check your work, if correct should be less than or equal to 68 (total number of regions in original df)
len(señorita)
# Out:
# 65

# %%
# truncate the data frame to only include the top ten countries by stream contribution for this song
señorita_top = señorita.head(10)
señorita_top
# Out:
#         date     title                        artist          region  \
# 206953  2019  Señorita  Shawn Mendes, Camila Cabello   United States
# 206910  2019  Señorita  Shawn Mendes, Camila Cabello         Germany
# 206928  2019  Señorita  Shawn Mendes, Camila Cabello          Mexico
# 206952  2019  Señorita  Shawn Mendes, Camila Cabello  United Kingdom
# 206895  2019  Señorita  Shawn Mendes, Camila Cabello          Brazil
# 206919  2019  Señorita  Shawn Mendes, Camila Cabello       Indonesia
# 206937  2019  Señorita  Shawn Mendes, Camila Cabello     Philippines
# 206930  2019  Señorita  Shawn Mendes, Camila Cabello     Netherlands
# 206897  2019  Señorita  Shawn Mendes, Camila Cabello          Canada
# 206891  2019  Señorita  Shawn Mendes, Camila Cabello       Australia
#
#         total streams
# 206953    178554964.0
# 206910     68105088.0
# 206928     64803176.0
# 206952     57663930.0
# 206895     57029178.0
# 206919     52376276.0
# 206937     42483717.0
# 206930     39025222.0
# 206897     37173138.0
# 206891     37083727.0

# %%
#create bar plot to show top 10 countries streams 
señorita_bar = señorita_top.plot.bar(x='region', y='total streams', figsize=(5, 5), width=.5, alpha=1, align="center", color = "lightgreen")

#add title
plt.title("Señorita: Top Regions (2019)")

#label xaxis
plt.xlabel("Country")

#lable yaxis
plt.ylabel("Streams (hundred millions)")

# top_countries_plot.bar_label(top_countries["total streams"], label_type='edge')

#adjust graph layout 
plt.tight_layout()

#export chart to pngs
plt.savefig("señorita_top_countries.png")

#show graph 
plt.show()

# %%
# create diagram to visualize how many of the top streaming contries were also a top contributor for this song 
venn2([set(top_ten.index), 
       set(señorita_top['region'].to_list())],
       set_labels=('Global', 'Señorita'),
       set_colors=('lightgreen', 'green'),
     )

# %%
# filter data frame to only display songs and streaming data for 2020
all_songs_2020 = chart_data[(chart_data["date"] == 2020)]

# sort dataframe by total streams (in descending order) to determine the most popular song from this year 
sorted_songs_2020 = all_songs_2020.sort_values('total streams', ascending = False)
sorted_songs_2020
# Out:
#         date                  title             artist    region  \
# 237896  2020        Blinding Lights         The Weeknd    Global
# 244984  2020           Dance Monkey        Tones And I    Global
# 289202  2020  Roses - Imanbek Remix          SAINt JHN    Global
# 300515  2020                The Box        Roddy Ricch    Global
# 247554  2020        Don't Start Now           Dua Lipa    Global
# ...      ...                    ...                ...       ...
# 317148  2020                ده و ده      Wegz, Abyusif     Egypt
# 251030  2020         F33l Lik3 Dyin      Playboi Carti  Bulgaria
# 284444  2020                Piccola       ElGrandeToto   Morocco
# 309286  2020                     X5  Kastrācija, Steps    Latvia
# 257328  2020            Hallucinate           Dua Lipa     Egypt
#
#         total streams
# 237896   1.645923e+09
# 244984   1.196398e+09
# 289202   1.040359e+09
# 300515   1.036463e+09
# 247554   1.025911e+09
# ...               ...
# 317148   1.001000e+03
# 251030   1.001000e+03
# 284444   1.001000e+03
# 309286   1.001000e+03
# 257328   1.001000e+03
#
# [90694 rows x 5 columns]

# %%
# create df for the most streamed song from this year sorted by top contributing regions (excluding global)
bl_2020 = sorted_songs_2020[(sorted_songs_2020["title"] == "Blinding Lights") & (chart_data["region"] != "Global")]
bl_2020
# Out:
# /var/folders/bp/kkf4c1nj557c5frmyn420c7c0000gn/T/ipykernel_49365/2590182737.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   bl_2020 = sorted_songs_2020[(sorted_songs_2020["title"] == "Blinding Lights") & (chart_data["region"] != "Global")]
#         date            title      artist          region  total streams
# 237940  2020  Blinding Lights  The Weeknd   United States    331037132.0
# 237913  2020  Blinding Lights  The Weeknd          Mexico    144665106.0
# 237895  2020  Blinding Lights  The Weeknd         Germany    122234476.0
# 237939  2020  Blinding Lights  The Weeknd  United Kingdom    113847572.0
# 237880  2020  Blinding Lights  The Weeknd          Brazil     81100838.0
# ...      ...              ...         ...             ...            ...
# 237881  2020  Blinding Lights  The Weeknd        Bulgaria      1170664.0
# 237917  2020  Blinding Lights  The Weeknd       Nicaragua      1055299.0
# 237914  2020  Blinding Lights  The Weeknd         Morocco      1052058.0
# 237890  2020  Blinding Lights  The Weeknd           Egypt       936518.0
# 237911  2020  Blinding Lights  The Weeknd      Luxembourg        61660.0
#
# [67 rows x 5 columns]

# %%
# check your work, if correct should be less than or equal to 68 (total number of regions in original df)
len(bl_2020)
# Out:
# 67

# %%
# truncate the data frame to only include the top ten countries by stream contribution for this song
bl_2020_top = bl_2020.head(10)
bl_2020_top
# Out:
#         date            title      artist          region  total streams
# 237940  2020  Blinding Lights  The Weeknd   United States    331037132.0
# 237913  2020  Blinding Lights  The Weeknd          Mexico    144665106.0
# 237895  2020  Blinding Lights  The Weeknd         Germany    122234476.0
# 237939  2020  Blinding Lights  The Weeknd  United Kingdom    113847572.0
# 237880  2020  Blinding Lights  The Weeknd          Brazil     81100838.0
# 237876  2020  Blinding Lights  The Weeknd       Australia     67035682.0
# 237894  2020  Blinding Lights  The Weeknd          France     65948733.0
# 237915  2020  Blinding Lights  The Weeknd     Netherlands     54929038.0
# 237932  2020  Blinding Lights  The Weeknd          Sweden     54271651.0
# 237882  2020  Blinding Lights  The Weeknd          Canada     54075826.0

# %%
# create bar plot to visualize how each of these top countries contributed 
bl_bar_2020 = bl_2020_top.plot.bar(x='region', y='total streams', figsize=(5, 5), width=.5, alpha=1, align="center", color = "lightgreen")

# add title
plt.title("Blinding Lights: Top Regions (2020)")

# label xaxis
plt.xlabel("Country")

# lable yaxis
plt.ylabel("Streams (hundred millions)")

# top_countries_plot.bar_label(top_countries["total streams"], label_type='edge')

# adjust graph layout 
plt.tight_layout()

# export chart to pngs
plt.savefig("blinding_lights_2020_top_countries.png")

# show graph 
plt.show()

# %%
# create diagram to visualize how many of the top streaming contries were also a top contributor for this song 
venn2([set(top_ten.index), 
       set(bl_2020_top['region'].to_list())],
       set_labels=('Global', 'Blinding Lights'),
       set_colors=('lightgreen', 'green'),
     )

# %%
# create new data frame that only includes songs and streaming data for 2021
all_songs_2021 = chart_data[(chart_data["date"] == 2021)]

# sort data frame by total streams to determine the most popular song from this year
sorted_songs_2021 = all_songs_2021.sort_values('total streams', ascending = False)

sorted_songs_2021
# Out:
#         date                                              title  \
# 396913  2021                                    drivers license
# 377424  2021                          STAY (with Justin Bieber)
# 360698  2021                     MONTERO (Call Me By Your Name)
# 397403  2021                                           good 4 u
# 357373  2021                          Levitating (feat. DaBaby)
# ...      ...                                                ...
# 350171  2021                               I'm Not The Only One
# 334949  2021                                          Dangerous
# 378497  2021                                     Save That Shit
# 383652  2021  Supersonic (My Existence) [with Noisia, josh p...
# 328826  2021                Bohemian Rhapsody - Remastered 2011
#
#                           artist     region  total streams
# 396913            Olivia Rodrigo     Global   1.166101e+09
# 377424             The Kid LAROI     Global   1.165565e+09
# 360698                 Lil Nas X     Global   1.129255e+09
# 397403            Olivia Rodrigo     Global   1.099668e+09
# 357373                  Dua Lipa     Global   9.595836e+08
# ...                          ...        ...            ...
# 350171                 Sam Smith  Nicaragua   1.001000e+03
# 334949  Kardinal Offishall, Akon  Lithuania   1.001000e+03
# 378497                  Lil Peep     Latvia   1.001000e+03
# 383652                  Skrillex    Estonia   1.001000e+03
# 328826                     Queen    Estonia   1.001000e+03
#
# [85830 rows x 5 columns]

# %%
# create df for the most streamed song from this year sorted by top contributing regions (excluding global)
drivers_license = sorted_songs_2021[(sorted_songs_2021["title"] == "drivers license") & (chart_data["region"] != "Global")]
drivers_license
# Out:
# /var/folders/bp/kkf4c1nj557c5frmyn420c7c0000gn/T/ipykernel_49365/1911991997.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   drivers_license = sorted_songs_2021[(sorted_songs_2021["title"] == "drivers license") & (chart_data["region"] != "Global")]
#         date            title          artist          region  total streams
# 396958  2021  drivers license  Olivia Rodrigo   United States    306465075.0
# 396957  2021  drivers license  Olivia Rodrigo  United Kingdom     81402221.0
# 396893  2021  drivers license  Olivia Rodrigo       Australia     53383305.0
# 396897  2021  drivers license  Olivia Rodrigo          Brazil     52823280.0
# 396930  2021  drivers license  Olivia Rodrigo          Mexico     51591263.0
# ...      ...              ...             ...             ...            ...
# 396934  2021  drivers license  Olivia Rodrigo       Nicaragua       561353.0
# 396898  2021  drivers license  Olivia Rodrigo        Bulgaria       519498.0
# 396955  2021  drivers license  Olivia Rodrigo         Ukraine       510396.0
# 396931  2021  drivers license  Olivia Rodrigo         Morocco       440354.0
# 396928  2021  drivers license  Olivia Rodrigo      Luxembourg        31074.0
#
# [68 rows x 5 columns]

# %%
# check your work, if correct should be less than or equal to 68 (total number of regions in original df)
len(drivers_license)
# Out:
# 68

# %%
# truncate the data frame to only include the top ten countries by stream contribution for this song
drivers_license_top = drivers_license.head(10)
drivers_license_top
# Out:
#         date            title          artist          region  total streams
# 396958  2021  drivers license  Olivia Rodrigo   United States    306465075.0
# 396957  2021  drivers license  Olivia Rodrigo  United Kingdom     81402221.0
# 396893  2021  drivers license  Olivia Rodrigo       Australia     53383305.0
# 396897  2021  drivers license  Olivia Rodrigo          Brazil     52823280.0
# 396930  2021  drivers license  Olivia Rodrigo          Mexico     51591263.0
# 396939  2021  drivers license  Olivia Rodrigo     Philippines     50715870.0
# 396912  2021  drivers license  Olivia Rodrigo         Germany     48208058.0
# 396921  2021  drivers license  Olivia Rodrigo       Indonesia     43175395.0
# 396899  2021  drivers license  Olivia Rodrigo          Canada     42631131.0
# 396932  2021  drivers license  Olivia Rodrigo     Netherlands     32669908.0

# %%
#create bar plot to show top 10 countries streams 
drivers_license_bar = drivers_license_top.plot.bar(x='region', y='total streams', figsize=(5, 5), width=.5, alpha=1, align="center", color = "lightgreen")

#add title
plt.title("drivers license: Top Regions (2021)")

#label xaxis
plt.xlabel("Country")

#lable yaxis
plt.ylabel("Streams (hundred millions)")

# top_countries_plot.bar_label(top_countries["total streams"], label_type='edge')

#adjust graph layout 
plt.tight_layout()

#export chart to pngs
plt.savefig("drivers_license_top_countries.png")

#show graph 
plt.show()

# %%
# create venn diagram to visualize how many of the top streaming contries were also a top contributor for song 
venn2([set(top_ten.index), 
       set(drivers_license_top['region'].to_list())],
       set_labels=('Global', 'drivers license'),
       set_colors=('lightgreen', 'green'),
     )

# %% [markdown]
# Question 3
# Which artists were the most influential globally (broken down by year)?

# %%
#group 2017 dataframe by artist
artist_2017 = df_2017.groupby("artist")

#sum total streams for each artists and sort to find top ten
top_artist_2017 = artist_2017["total streams"].sum().sort_values(ascending=False).head(10)

#print top artists 2021 
top_artist_2017
# Out:
# artist
# Ed Sheeran                                 4.275284e+09
# Kendrick Lamar                             1.709399e+09
# Drake                                      1.400295e+09
# Imagine Dragons                            1.119721e+09
# Lil Uzi Vert                               1.043798e+09
# Clean Bandit                               9.692920e+08
# Bruno Mars                                 9.183314e+08
# DJ Khaled                                  9.127952e+08
# Luis Fonsi, Daddy Yankee, Justin Bieber    9.013116e+08
# Future                                     8.608916e+08
# Name: total streams, dtype: float64

# %%
#plot top ten artists 2017
artists_2017_plot = top_artist_2017.plot.bar(x = 'artist', y='streams', figsize=(5, 5), width=.5, alpha=1, align="center", color = "lightgreen")

#add title
plt.title("Top Ten Artists Globally By Streaming in 2017")

#label xaxis
plt.xlabel("Artist")

#lable yaxis
plt.ylabel("Streams (in billions)")

#show graph 
plt.show()

# %%
#group 2018 dataframe by artist
artist_2018 = df_2018.groupby("artist")

#sum total streams for each artists and sort to find top ten
top_artist_2018 = artist_2018["total streams"].sum().sort_values(ascending=False).head(10)

#print top artists 2021 
top_artist_2018
# Out:
# artist
# Drake              3.611026e+09
# Post Malone        3.526200e+09
# XXXTENTACION       3.159304e+09
# Ariana Grande      1.640970e+09
# Ed Sheeran         1.452187e+09
# Travis Scott       1.330752e+09
# Khalid             1.171441e+09
# Juice WRLD         1.102055e+09
# Imagine Dragons    1.071658e+09
# Dua Lipa           1.035104e+09
# Name: total streams, dtype: float64

# %%
#plot top ten artists 2018 
artists_2018_plot = top_artist_2018.plot.bar(x = 'artist', y='streams', figsize=(5, 5), width=.5, alpha=1, align="center", color = "lightgreen")

#add title
plt.title("Top Ten Artists Globally By Streaming in 2018")

#label xaxis
plt.xlabel("Artist")

#lable yaxis
plt.ylabel("Streams (in billions)")

#show graph 
plt.show()

# %%
#group 2019 dataframe by artist
artist_2019 = df_2019.groupby("artist")

#sum total streams for each artists and sort to find top ten
top_artist_2019 = artist_2019["total streams"].sum().sort_values(ascending=False).head(10)

#print top artists 2021 
top_artist_2019
# Out:
# artist
# Billie Eilish                   3.646866e+09
# Post Malone                     3.474732e+09
# Ariana Grande                   3.007082e+09
# Ed Sheeran                      2.534931e+09
# Juice WRLD                      1.411361e+09
# Khalid                          1.355242e+09
# Lil Nas X                       1.272347e+09
# Lewis Capaldi                   1.108973e+09
# Taylor Swift                    1.068860e+09
# Shawn Mendes, Camila Cabello    1.066058e+09
# Name: total streams, dtype: float64

# %%
#plot top ten artists 2021 
artists_2019_plot = top_artist_2019.plot.bar(x = 'artist', y='streams', figsize=(5, 5), width=.5, alpha=1, align="center", color = "lightgreen")

#add title
plt.title("Top Ten Artists Globally By Streaming in 2019")

#label xaxis
plt.xlabel("Artist")

#lable yaxis
plt.ylabel("Streams (in billions)")

#show graph 
plt.show()

# %%
#group 2020 dataframe by artist
artist_2020 = df_2020.groupby("artist")

#sum total streams for each artists and sort to find top ten
top_artist_2020 = artist_2020["total streams"].sum().sort_values(ascending=False).head(10)

#print top artists 2020 
top_artist_2020
# Out:
# artist
# Juice WRLD       2.674079e+09
# The Weeknd       2.387795e+09
# Bad Bunny        2.015389e+09
# Dua Lipa         1.954281e+09
# Billie Eilish    1.915002e+09
# Pop Smoke        1.727656e+09
# Harry Styles     1.663451e+09
# Justin Bieber    1.584570e+09
# DaBaby           1.507142e+09
# Lewis Capaldi    1.490480e+09
# Name: total streams, dtype: float64

# %%
#plot top ten artists 2021 
artists_2020_plot = top_artist_2020.plot.bar(x = 'artist', y='streams', figsize=(5, 5), width=.5, alpha=1, align="center", color = "lightgreen")

#add title
plt.title("Top Ten Artists Globally By Streaming in 2020")

#label xaxis
plt.xlabel("Artist")

#lable yaxis
plt.ylabel("Streams (in billions)")

#show graph 
plt.show()

# %%
#group 2021 dataframe by artist
artist_2021 = df_2021.groupby("artist")

#sum total streams for each artists and sort to find top ten
top_artist_2021 = artist_2021["total streams"].sum().sort_values(ascending=False).head(10)

#print top artists 2021 
top_artist_2021
# Out:
# artist
# Olivia Rodrigo    4.447896e+09
# Doja Cat          2.415020e+09
# Lil Nas X         2.297249e+09
# The Weeknd        2.274906e+09
# Justin Bieber     2.051325e+09
# The Kid LAROI     1.734745e+09
# Drake             1.733165e+09
# Dua Lipa          1.650767e+09
# BTS               1.577504e+09
# Ed Sheeran        1.562194e+09
# Name: total streams, dtype: float64

# %%
#plot top ten artists 2021 
artists_2021_plot = top_artist_2021.plot.bar(x = 'artist', y='streams', figsize=(5, 5), width=.5, alpha=1, align="center", color = "lightgreen")

#add title
plt.title("Top Ten Artists Globally By Streaming in 2021")

#label xaxis
plt.xlabel("Artist")

#lable yaxis
plt.ylabel("Streams (in billions)")

#show graph 
plt.show()
